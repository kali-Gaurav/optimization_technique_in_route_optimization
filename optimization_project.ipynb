# %%
import pandas as pd
import numpy as np
from collections import deque
from datetime import datetime, timedelta

def main():
    print("\n=== Train Route Finder ===")
    print("Finds connecting routes between any two stations with distance, time, and cost calculations\n")

    # Load the data
    try:
        df = pd.read_csv('Train_details.csv')

        # Keep only trains with 5-digit train numbers
        df = df[df['Train No'].astype(str).str.len() == 5]

        # Add random Seat Availability (0 or 1)
        df['Seat Availability'] = np.random.choice([0, 1], size=len(df),p=[0,1])

        print("Successfully loaded train schedule data.")
    except FileNotFoundError:
        print("Error: Could not find 'Train_details.csv'. Please ensure the file is in the same directory.")
        return
    except Exception as e:
        print(f"Error loading data: {str(e)}")
        return

    # Get user input
    while True:
        print("\nEnter station codes (3-4 letter codes like PGT, KOTA, etc.)")
        source = input("Enter origin station code: ").strip().upper()
        destination = input("Enter destination station code: ").strip().upper()

        if source not in df['Station Code'].values:
            print(f"Error: Station code '{source}' not found in database.")
            continue
        if destination not in df['Station Code'].values:
            print(f"Error: Station code '{destination}' not found in database.")
            continue
        break

    while True:
        try:
            max_connections = int(input("Enter maximum number of connections (1-4 recommended): "))
            if 0 <= max_connections <= 4:
                break
            print("Please enter a number between 0 and 4")
        except ValueError:
            print("Please enter a valid number")

    output_file = f"{source}_to_{destination}_routes.csv"
    routes_df = find_and_save_routes(df, source, destination, max_connections, output_file)

    if routes_df is not None:
        print("\nAnalysis of found routes:")
        analyze_routes(routes_df)
        print(f"\nDetailed routes saved to: {output_file}")

def find_and_save_routes(df, source, destination, max_connections=3, output_file='connecting_routes.csv'):
    graph = {}
    train_info = {}

    for _, row in df.iterrows():
        train_no = row['Train No']
        station = row['Station Code']
        dest_station = row['Destination Station']
        distance = row['Distance']

        if station not in graph:
            graph[station] = {}
        if train_no not in graph[station]:
            graph[station][train_no] = dest_station

        if train_no not in train_info:
            train_info[train_no] = {
                'name': row['Train Name'],
                'seq': {},
                'source': row['Source Station'],
                'dest': row['Destination Station'],
                'seat_availability': row['Seat Availability']
            }

        train_info[train_no]['seq'][row['SEQ']] = {
            'station': station,
            'arrival': row['Arrival time'],
            'departure': row['Departure Time'],
            'distance': distance
        }

    def calculate_time_diff(start_time, end_time):
        try:
            fmt = '%H:%M:%S'
            t1 = datetime.strptime(start_time, fmt)
            t2 = datetime.strptime(end_time, fmt)
            if t2 < t1:
                t2 += timedelta(days=1)
            return (t2 - t1).total_seconds() / 3600
        except:
            return 0

    def format_time(hours):
        """Formats time in hours to HHh MMm format."""
        hr = int(hours)
        mins = int((hours % 1) * 60)
        return f"{hr}h {mins}m"

    # Logic to find nearby stations with direct trains to destination within 100km range of palakad
    def find_nearby_stations_with_direct_trains(source, destination, max_distance=100):
        nearby_stations = set()

        # Get trains originating from palakad
        source_trains = df[df['Source Station'] == source]['Train No'].unique()

        # Iterate through each train originating from palakad
        for train in source_trains:
            # Get the sequence of stations for this train
            train_data = df[df['Train No'] == train].sort_values('Distance')

            # If palakad is in the sequence, find nearby stations
            if source in train_data['Station Code'].values:
                # Convert 'Distance' column to numeric, handling errors
                train_data['Distance'] = pd.to_numeric(train_data['Distance'], errors='coerce')
                source_distance = train_data[train_data['Station Code'] == source]['Distance'].values[0]

                # Find nearby stations within the max distance
                near_stations = train_data[abs(train_data['Distance'] - source_distance) <= max_distance]

                # Check if nearby stations have direct trains to the destination
                for station in near_stations['Station Code'].values:
                    if station != source and destination in df[df['Station Code'] == station]['Destination Station'].values:
                        nearby_stations.add(station)
        print(nearby_stations)

        return nearby_stations


    def bfs(start, end, max_depth):
        queue = deque()
        queue.append((start, [], 0))
        visited = set()
        routes = []

        while queue:
            current, path, depth = queue.popleft()
            if current == end:
                routes.append(path)
                continue
            if depth >= max_depth:
                continue
            if current in visited:
                continue
            visited.add(current)
            if current not in graph:
                continue
            for train_no, next_station in graph[current].items():
                seq_info = train_info[train_no]['seq']
                stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
                try:
                    current_idx = stations_in_order.index(current)
                    next_idx = stations_in_order.index(next_station)
                    if next_idx > current_idx:
                        new_path = path + [(train_no, current, next_station)]
                        queue.append((next_station, new_path, depth + 1))
                except ValueError:
                    continue
        return routes

    all_routes = []
    for connections in range(1, max_connections + 1):
        routes = bfs(source, destination, connections)
        all_routes.extend(routes)

    csv_data = []
    for route_num, route in enumerate(all_routes, 1):
        total_trains = len(route)
        total_distance = 0
        total_duration_hours = 0
        route_segments = []

        for segment in route:
            train_no, from_station, to_station = segment
            train_name = train_info[train_no]['name']
            seat_available = train_info[train_no]['seat_availability']

            seq_info = train_info[train_no]['seq']
            for seq, info in seq_info.items():
                if info['station'] == from_station:
                    departure = info['departure']
                    from_distance = float(info['distance'])
                if info['station'] == to_station:
                    arrival = info['arrival']
                    to_distance = float(info['distance'])

            segment_distance = abs(to_distance - from_distance)
            total_distance += segment_distance

             # Calculate segment duration based on distance
            if segment_distance > 1800:
                segment_duration = segment_distance / 58  # Superfast long-distance
            elif segment_distance > 1000:
                segment_duration = segment_distance / 60
            elif segment_distance > 500:
                segment_duration = segment_distance / 55
            elif segment_distance > 300:
                segment_duration = segment_distance / 50
            elif segment_distance > 150:
                segment_duration = segment_distance / 45
            else:
                segment_duration = segment_distance / 38  # Local or short distance
            wait_time = 0
            total_duration_hours += segment_duration
            if route.index(segment) > 0:
                prev_arrival = route_segments[-1]['Arrival Time']
                wait_time = calculate_time_diff(prev_arrival, departure)
                if wait_time < 0:
                    wait_time += 24
                total_duration_hours += wait_time

            route_segments.append({
                'Train Number': train_no,
                'Train Name': train_name,
                'From Station': from_station,
                'Departure Time': departure,
                'To Station': to_station,
                'Arrival Time': arrival,
                'Segment Distance (km)': segment_distance,
                'Segment Duration (hrs)': format_time(segment_duration),
                'Seat Availability': seat_available,
                'Waiting Time Before Segment (hrs)': format_time(wait_time)


            })

        total_cost = total_distance * 1
        hours = int(total_duration_hours)
        minutes = int((total_duration_hours % 1) * 60)
        total_duration = f"{hours}h {minutes}m"

        for segment_num, segment in enumerate(route_segments, 1):
            csv_data.append({
                'Route Number': route_num,
                'Total Trains in Route': total_trains,
                'Segment Number': segment_num,
                'Train Number': segment['Train Number'],
                'Train Name': segment['Train Name'],
                'From Station': segment['From Station'],
                'Departure Time': segment['Departure Time'],
                'To Station': segment['To Station'],
                'Arrival Time': segment['Arrival Time'],
                'Segment Distance (km)': segment['Segment Distance (km)'],
                'Segment Duration (hrs)': segment['Segment Duration (hrs)'],
                'Seat Availability': segment['Seat Availability'],
                'Waiting Time Before Segment (hrs)': segment['Waiting Time Before Segment (hrs)'],
                'Total Route Distance (km)': total_distance,
                'Total Route Duration': total_duration,
                'Estimated Cost (₹)': total_cost
            })

    if csv_data:
        routes_df = pd.DataFrame(csv_data)
        columns = [
            'Route Number', 'Total Trains in Route', 'Segment Number',
            'Train Number', 'Train Name', 'From Station', 'Departure Time',
            'To Station', 'Arrival Time', 'Segment Distance (km)',
            'Segment Duration (hrs)', 'Seat Availability', 'Waiting Time Before Segment (hrs)',
            'Total Route Distance (km)', 'Total Route Duration', 'Estimated Cost (₹)'
        ]
        routes_df = routes_df[columns]
        routes_df.to_csv(output_file, index=False)
        print(f"\nSuccessfully saved {len(all_routes)} routes to {output_file}")
        return routes_df
    else:
        print("\nNo valid routes found with the given parameters.")
        return None

def analyze_routes(routes_df):
    unique_routes = routes_df['Route Number'].unique()
    print(f"\nFound {len(unique_routes)} unique routes:")

    for route_num in unique_routes:
        route_data = routes_df[routes_df['Route Number'] == route_num]
        first_row = route_data.iloc[0]
        print(f"\nRoute {route_num}:")
        print(f"- Trains required: {first_row['Total Trains in Route']}")
        print(f"- Total distance: {first_row['Total Route Distance (km)']} km")
        print(f"- Total duration: {first_row['Total Route Duration']}")
        print(f"- Estimated cost: ₹{first_row['Estimated Cost (₹)']}")

        print("  Segments:")
        for _, segment in route_data.iterrows():
            print(f"  {segment['Segment Number']}. {segment['Train Name']} ({segment['Train Number']})")
            print(f"     {segment['From Station']} ({segment['Departure Time']}) → {segment['To Station']} ({segment['Arrival Time']})")
            print(f"     Distance: {segment['Segment Distance (km)']} km | Duration: {segment['Segment Duration (hrs)']} hrs | Seat Available: {segment['Seat Availability']}")

    routes_summary = routes_df.drop_duplicates('Route Number')

    if len(routes_summary) > 1:
        fastest = routes_summary.loc[routes_summary['Total Route Duration'].idxmin()]
        shortest = routes_summary.loc[routes_summary['Total Route Distance (km)'].idxmin()]
        cheapest = routes_summary.loc[routes_summary['Estimated Cost (₹)'].idxmin()]

        print("\nRecommendations:")
        print(f"- Fastest route: Route {fastest['Route Number']} ({fastest['Total Route Duration']})")
        print(f"- Shortest route: Route {shortest['Route Number']} ({shortest['Total Route Distance (km)']} km)")
        print(f"- Cheapest route: Route {cheapest['Route Number']} (₹{cheapest['Estimated Cost (₹)']})")

if __name__ == "__main__":
    main()
# Out:
# === Train Route Finder ===
# Finds connecting routes between any two stations with distance, time, and cost calculations
# C:\Users\Gaurav Nagar\AppData\Local\Temp\ipykernel_12608\3877280324.py:12: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Train_details.csv')
# Successfully loaded train schedule data.
#
# Enter station codes (3-4 letter codes like PGT, KOTA, etc.)
#
# Successfully saved 153 routes to PGT_to_KOTA_routes.csv
#
# Analysis of found routes:
#
# Found 153 unique routes:
#
# Route 1:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 2:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 3:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 4:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 5:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 6:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 7:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 8:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 9:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 10:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 11:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 12:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 13:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 14:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 15:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 16:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 17:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12h 39m hrs | Seat Available: 1
#
# Route 18:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12h 40m hrs | Seat Available: 1
#
# Route 19:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17h 0m hrs | Seat Available: 1
#
# Route 20:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17h 41m hrs | Seat Available: 1
#
# Route 21:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 22:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 23:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8h 14m hrs | Seat Available: 1
#
# Route 24:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17h 30m hrs | Seat Available: 1
#
# Route 25:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17h 12m hrs | Seat Available: 1
#
# Route 26:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22h 53m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11h 21m hrs | Seat Available: 1
#
# Route 27:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 28:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 29:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 30:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 31:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 32:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3h 38m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15h 6m hrs | Seat Available: 1
#
# Route 33:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20h 36m hrs | Seat Available: 1
#
# Route 34:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19h 48m hrs | Seat Available: 1
#
# Route 35:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21h 34m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11h 54m hrs | Seat Available: 1
#
# Route 36:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3h 29m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11h 9m hrs | Seat Available: 1
#
# Route 37:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 38:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 39:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14h 16m hrs | Seat Available: 1
#
# Route 40:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13h 58m hrs | Seat Available: 1
#
# Route 41:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9h 28m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16h 42m hrs | Seat Available: 1
#
# Route 42:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 43:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 44:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. ROK INTERCIT (14323)
#      NDLS (10:35:00) → ROK (12:55:00)
#      Distance: 71.0 km | Duration: 1h 52m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      ROK (11:20:00) → KOTA (23:50:00)
#      Distance: 528.0 km | Duration: 9h 35m hrs | Seat Available: 1
#
# Route 45:
# - Trains required: 3
# - Total distance: 4375.0 km
# - Total duration: 95h 8m
# - Estimated cost: ₹4375.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11h 26m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      UHP (22:25:00) → KOTA (23:50:00)
#      Distance: 1103.0 km | Duration: 18h 22m hrs | Seat Available: 1
#
# Route 46:
# - Trains required: 3
# - Total distance: 4358.0 km
# - Total duration: 87h 1m
# - Estimated cost: ₹4358.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11h 26m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UHP (14:35:00) → KOTA (11:10:00)
#      Distance: 1086.0 km | Duration: 18h 6m hrs | Seat Available: 1
#
# Route 47:
# - Trains required: 3
# - Total distance: 3188.0 km
# - Total duration: 90h 51m
# - Estimated cost: ₹3188.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-SNP 12C (64003)
#      NDLS (05:00:00) → SNP (06:10:00)
#      Distance: 44.0 km | Duration: 1h 9m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      SNP (01:56:00) → KOTA (11:10:00)
#      Distance: 501.0 km | Duration: 9h 6m hrs | Seat Available: 1
#
# Route 48:
# - Trains required: 3
# - Total distance: 3279.0 km
# - Total duration: 67h 16m
# - Estimated cost: ₹3279.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. GZB-PNP MEMU (64471)
#      NDLS (18:07:00) → PNP (20:20:00)
#      Distance: 89.0 km | Duration: 2h 20m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      PNP (01:23:00) → KOTA (11:10:00)
#      Distance: 547.0 km | Duration: 9h 56m hrs | Seat Available: 1
#
# Route 49:
# - Trains required: 3
# - Total distance: 3101.0 km
# - Total duration: 77h 47m
# - Estimated cost: ₹3101.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SSB-BVH-PWL (64908)
#      NDLS (06:30:00) → BVH (07:35:00)
#      Distance: 33.0 km | Duration: 0h 52m hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      BVH (13:41:00) → KOTA (20:00:00)
#      Distance: 425.0 km | Duration: 8h 30m hrs | Seat Available: 1
#
# Route 50:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 95h 15m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1h 17m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1196.0 km | Duration: 19h 56m hrs | Seat Available: 1
#
# Route 51:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 28m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1h 17m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1149.0 km | Duration: 19h 8m hrs | Seat Available: 1
#
# Route 52:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 93h 30m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 1038.0 km | Duration: 17h 18m hrs | Seat Available: 1
#
# Route 53:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 13m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 991.0 km | Duration: 18h 1m hrs | Seat Available: 1
#
# Route 54:
# - Trains required: 3
# - Total distance: 4083.0 km
# - Total duration: 92h 59m
# - Estimated cost: ₹4083.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1128.0 km | Duration: 18h 48m hrs | Seat Available: 1
#
# Route 55:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 92h 12m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1081.0 km | Duration: 18h 0m hrs | Seat Available: 1
#
# Route 56:
# - Trains required: 3
# - Total distance: 3715.0 km
# - Total duration: 86h 0m
# - Estimated cost: ₹3715.0
#   Segments:
#   1. MAQ MS EXP (16860)
#      PGT (13:45:00) → MS (04:15:00)
#      Distance: 632.0 km | Duration: 11h 29m hrs | Seat Available: 1
#   2. SHRADDHA SET (16793)
#      MS (13:00:00) → FD (08:30:00)
#      Distance: 2259.0 km | Duration: 38h 56m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      FD (20:20:00) → KOTA (12:55:00)
#      Distance: 824.0 km | Duration: 14h 58m hrs | Seat Available: 1
#
# Route 57:
# - Trains required: 3
# - Total distance: 3412.0 km
# - Total duration: 64h 19m
# - Estimated cost: ₹3412.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. JP-SOG PASSA (59706)
#      BKN (14:30:00) → SOG (18:10:00)
#      Distance: 181.0 km | Duration: 4h 1m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SOG (19:55:00) → KOTA (09:50:00)
#      Distance: 803.0 km | Duration: 14h 35m hrs | Seat Available: 1
#
# Route 58:
# - Trains required: 3
# - Total distance: 3434.0 km
# - Total duration: 84h 21m
# - Estimated cost: ₹3434.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDORE BHIND (21125)
#      INDB (20:05:00) → BIX (09:50:00)
#      Distance: 643.0 km | Duration: 11h 41m hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      BIX (18:10:00) → KOTA (09:45:00)
#      Distance: 499.0 km | Duration: 9h 58m hrs | Seat Available: 1
#
# Route 59:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 52h 40m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3h 30m hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      NAD (14:40:00) → KOTA (19:45:00)
#      Distance: 221.0 km | Duration: 4h 54m hrs | Seat Available: 1
#
# Route 60:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 54h 15m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3h 30m hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      NAD (16:15:00) → KOTA (22:30:00)
#      Distance: 221.0 km | Duration: 4h 54m hrs | Seat Available: 1
#
# Route 61:
# - Trains required: 3
# - Total distance: 2675.0 km
# - Total duration: 53h 45m
# - Estimated cost: ₹2675.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      RTM (13:20:00) → KOTA (19:45:00)
#      Distance: 265.0 km | Duration: 5h 53m hrs | Seat Available: 1
#
# Route 62:
# - Trains required: 3
# - Total distance: 2676.0 km
# - Total duration: 55h 17m
# - Estimated cost: ₹2676.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      RTM (14:50:00) → KOTA (22:30:00)
#      Distance: 266.0 km | Duration: 5h 54m hrs | Seat Available: 1
#
# Route 63:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 64:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 65:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 66:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 67:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 68:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 69:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 1
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 70:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 71:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12h 39m hrs | Seat Available: 1
#
# Route 72:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12h 40m hrs | Seat Available: 1
#
# Route 73:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17h 0m hrs | Seat Available: 1
#
# Route 74:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17h 41m hrs | Seat Available: 1
#
# Route 75:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 76:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 77:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8h 14m hrs | Seat Available: 1
#
# Route 78:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17h 30m hrs | Seat Available: 1
#
# Route 79:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17h 12m hrs | Seat Available: 1
#
# Route 80:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22h 53m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11h 21m hrs | Seat Available: 1
#
# Route 81:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 82:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 83:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 84:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 85:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 86:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3h 38m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15h 6m hrs | Seat Available: 1
#
# Route 87:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20h 36m hrs | Seat Available: 1
#
# Route 88:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19h 48m hrs | Seat Available: 1
#
# Route 89:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21h 34m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11h 54m hrs | Seat Available: 1
#
# Route 90:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3h 29m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11h 9m hrs | Seat Available: 1
#
# Route 91:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 92:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 93:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14h 16m hrs | Seat Available: 1
#
# Route 94:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13h 58m hrs | Seat Available: 1
#
# Route 95:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9h 28m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16h 42m hrs | Seat Available: 1
#
# Route 96:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 97:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 98:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. ROK INTERCIT (14323)
#      NDLS (10:35:00) → ROK (12:55:00)
# ...
#      JP (06:40:00) → BXN (12:55:00)
#      Distance: 268.0 km | Duration: 5h 57m hrs | Seat Available: 1
#   4. JAB-KOTA PAS (59814)
#      BXN (10:50:00) → KOTA (17:15:00)
#      Distance: 244.0 km | Duration: 5h 25m hrs | Seat Available: 1
#
# Route 130:
# - Trains required: 4
# - Total distance: 4195.0 km
# - Total duration: 116h 19m
# - Estimated cost: ₹4195.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 1
#   3. BIN-GWL PASS (51884)
#      GWL (08:30:00) → BINA (17:45:00)
#      Distance: 345.0 km | Duration: 6h 54m hrs | Seat Available: 1
#   4. BINA-KOTA PA (51612)
#      BINA (10:00:00) → KOTA (18:50:00)
#      Distance: 303.0 km | Duration: 6h 3m hrs | Seat Available: 1
#
# Route 131:
# - Trains required: 4
# - Total distance: 4753.0 km
# - Total duration: 124h 9m
# - Estimated cost: ₹4753.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17h 18m hrs | Seat Available: 1
#   3. HSR-JIND PAS (54044)
#      HSR (05:00:00) → JIND (14:50:00)
#      Distance: 327.0 km | Duration: 6h 32m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JIND (10:27:00) → KOTA (23:50:00)
#      Distance: 585.0 km | Duration: 10h 38m hrs | Seat Available: 1
#
# Route 132:
# - Trains required: 4
# - Total distance: 4711.0 km
# - Total duration: 102h 57m
# - Estimated cost: ₹4711.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17h 18m hrs | Seat Available: 1
#   3. DUI JHL HSR (54631)
#      HSR (18:10:00) → DUI (21:35:00)
#      Distance: 147.0 km | Duration: 3h 52m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      DUI (07:00:00) → KOTA (23:50:00)
#      Distance: 723.0 km | Duration: 13h 8m hrs | Seat Available: 1
#
# Route 133:
# - Trains required: 4
# - Total distance: 4784.0 km
# - Total duration: 119h 20m
# - Estimated cost: ₹4784.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24h 57m hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3h 45m hrs | Seat Available: 1
#   4. NMH - KOTA E (29019)
#      NMH (14:40:00) → KOTA (18:45:00)
#      Distance: 228.0 km | Duration: 5h 3m hrs | Seat Available: 1
#
# Route 134:
# - Trains required: 4
# - Total distance: 4783.0 km
# - Total duration: 103h 9m
# - Estimated cost: ₹4783.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24h 57m hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3h 45m hrs | Seat Available: 1
#   4. NMH-KOTA FAS (59834)
#      NMH (22:30:00) → KOTA (04:45:00)
#      Distance: 227.0 km | Duration: 5h 2m hrs | Seat Available: 1
#
# Route 135:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 126h 9m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. KOTA JANSHTB (12060)
#      SWM (18:07:00) → KOTA (20:00:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 136:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 137:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 138:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 105h 21m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      SWM (21:20:00) → KOTA (23:50:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 139:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 117h 28m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. UHP-KOTA WEE (19806)
#      SWM (09:27:00) → KOTA (11:10:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 140:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 111h 12m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. JP-KOTA EXP (19808)
#      SWM (03:10:00) → KOTA (05:20:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 141:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 115h 57m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. KOTA-HMH -KO (22982)
#      SWM (07:55:00) → KOTA (09:50:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 142:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 122h 1m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. JAB-KOTA PAS (59814)
#      SWM (14:00:00) → KOTA (17:15:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 143:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 127h 55m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. KOTA JANSHTB (12060)
#      BTE (15:50:00) → KOTA (20:00:00)
#      Distance: 287.0 km | Duration: 6h 22m hrs | Seat Available: 1
#
# Route 144:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 120h 18m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 145:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 120h 20m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 287.0 km | Duration: 6h 22m hrs | Seat Available: 1
#
# Route 146:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 130h 42m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      BTE (18:39:00) → KOTA (23:50:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 147:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 118h 58m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. UHP-KOTA WEE (19806)
#      BTE (06:55:00) → KOTA (11:10:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 148:
# - Trains required: 4
# - Total distance: 4593.0 km
# - Total duration: 113h 20m
# - Estimated cost: ₹4593.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SDAH BUI EXP (13105)
#      BJU (23:55:00) → BUI (06:10:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   3. BUI - SHG  P (55137)
#      BUI (05:25:00) → SHG (11:15:00)
#      Distance: 167.0 km | Duration: 3h 42m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      SHG (18:18:00) → KOTA (12:55:00)
#      Distance: 929.0 km | Duration: 16h 53m hrs | Seat Available: 1
#
# Route 149:
# - Trains required: 4
# - Total distance: 5154.0 km
# - Total duration: 119h 41m
# - Estimated cost: ₹5154.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DELHI JIND P (54033)
#      DLI (17:25:00) → NRW (22:25:00)
#      Distance: 160.0 km | Duration: 3h 33m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      NRW (09:30:00) → KOTA (23:50:00)
#      Distance: 619.0 km | Duration: 11h 15m hrs | Seat Available: 1
#
# Route 150:
# - Trains required: 4
# - Total distance: 5231.0 km
# - Total duration: 119h 35m
# - Estimated cost: ₹5231.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DELHI JIND J (54035)
#      DLI (15:40:00) → JHL (21:40:00)
#      Distance: 199.0 km | Duration: 4h 25m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JHL (08:50:00) → KOTA (23:50:00)
#      Distance: 657.0 km | Duration: 11h 56m hrs | Seat Available: 1
#
# Route 151:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4h 30m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8h 2m hrs | Seat Available: 1
#
# Route 152:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4h 30m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8h 2m hrs | Seat Available: 1
#
# Route 153:
# - Trains required: 4
# - Total distance: 4536.0 km
# - Total duration: 120h 51m
# - Estimated cost: ₹4536.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. HW BL SUP EX (12912)
#      NZM (23:35:00) → BL (18:20:00)
#      Distance: 1176.0 km | Duration: 19h 36m hrs | Seat Available: 1
#   3. BL-DHD INTER (12929)
#      BL (07:15:00) → DHD (13:25:00)
#      Distance: 344.0 km | Duration: 6h 52m hrs | Seat Available: 1
#   4. BRC-KOTA PAR (59831)
#      DHD (11:25:00) → KOTA (22:30:00)
#      Distance: 381.0 km | Duration: 7h 37m hrs | Seat Available: 1
#
# Recommendations:
# - Fastest route: Route 44 (100h 17m)
# - Shortest route: Route 59 (2646.0 km)
# - Cheapest route: Route 59 (₹2646.0)
#
# Detailed routes saved to: PGT_to_KOTA_routes.csv

# %%
import pandas as pd
import numpy as np
from collections import deque
from datetime import datetime, timedelta

def main():
    print("\n=== Train Route Finder ===")
    print("Finds connecting routes between any two stations with distance, time, and cost calculations\n")

    # Load the data
    try:
        df = pd.read_csv('Train_details.csv')

        # Keep only trains with 5-digit train numbers
        df = df[df['Train No'].astype(str).str.len() == 5]

        # Add random Seat Availability (0 or 1)
        df['Seat Availability'] = np.random.choice([0, 1], size=len(df),p=[0.2,0.8])

        print("Successfully loaded train schedule data.")
    except FileNotFoundError:
        print("Error: Could not find 'Train_details.csv'. Please ensure the file is in the same directory.")
        return
    except Exception as e:
        print(f"Error loading data: {str(e)}")
        return

    # Get user input
    while True:
        print("\nEnter station codes (3-4 letter codes like PGT, KOTA, etc.)")
        source = input("Enter origin station code: ").strip().upper()
        destination = input("Enter destination station code: ").strip().upper()

        if source not in df['Station Code'].values:
            print(f"Error: Station code '{source}' not found in database.")
            continue
        if destination not in df['Station Code'].values:
            print(f"Error: Station code '{destination}' not found in database.")
            continue
        break

    while True:
        try:
            max_connections = int(input("Enter maximum number of connections (1-4 recommended): "))
            if 0 <= max_connections <= 4:
                break
            print("Please enter a number between 0 and 4")
        except ValueError:
            print("Please enter a valid number")

    output_file = f"{source}_to_{destination}_routes.csv"
    routes_df = find_and_save_routes(df, source, destination, max_connections, output_file)

    if routes_df is not None:
        print("\nAnalysis of found routes:")
        analyze_routes(routes_df)
        print(f"\nDetailed routes saved to: {output_file}")
        print("\n=== Nearby 2-hour junctions to catch train to destination ===")
        suggest_nearby_junctions(df, source, destination)

# def suggest_nearby_junctions(df, source, destination):  # Define the function at the top level
#     # Get all station codes that appear in the data
#     station_codes = df['Station Code'].unique()

#     # Find distances from source to all other stations (ignoring direct train requirement)
#     source_rows = df[df['Station Code'] == source]
#     nearby_station_codes = set()

#     for train in source_rows['Train No'].unique():
#           train_data = df[df['Train No'] == train].sort_values('Distance')
#           if source in train_data['Station Code'].values:
#               # Convert 'Distance' column to numeric, handling errors
#               train_data['Distance'] = pd.to_numeric(train_data['Distance'], errors='coerce')
#               source_distance = train_data[train_data['Station Code'] == source]['Distance'].values[0]
#               train_data['DistanceFromSource'] = abs(train_data['Distance'] - source_distance)
#               near_stations = train_data[train_data['DistanceFromSource'] <= 150]
#               nearby_station_codes.update(near_stations['Station Code'].values)
#     # Now check if these nearby stations have a direct train to the destination
#     potential_junctions = []
#     for station in nearby_station_codes:
#         direct = df[(df['Station Code'] == station) & (df['Destination Station'] == destination)]
#         if not direct.empty:
#             potential_junctions.append((station, round(direct['Distance'].values[0], 2)))

#     if potential_junctions:
#         print("\nStations within ~2 hours (~150 km) that have direct train to destination:")
#         for junc, dist in potential_junctions:
#             print(f"- {junc} ({dist} km approx. from {source})")
#     else:
#         print("No nearby junctions found with direct train to destination within 2 hours travel.")

def find_and_save_routes(df, source, destination, max_connections=3, output_file='connecting_routes.csv'):
    graph = {}
    train_info = {}

    for _, row in df.iterrows():
        train_no = row['Train No']
        station = row['Station Code']
        dest_station = row['Destination Station']
        distance = row['Distance']

        if station not in graph:
            graph[station] = {}
        if train_no not in graph[station]:
            graph[station][train_no] = dest_station

        if train_no not in train_info:
            train_info[train_no] = {
                'name': row['Train Name'],
                'seq': {},
                'source': row['Source Station'],
                'dest': row['Destination Station'],
                'seat_availability': row['Seat Availability']
            }

        train_info[train_no]['seq'][row['SEQ']] = {
            'station': station,
            'arrival': row['Arrival time'],
            'departure': row['Departure Time'],
            'distance': distance
        }

    def calculate_time_diff(start_time, end_time):
        try:
            fmt = '%H:%M:%S'
            t1 = datetime.strptime(start_time, fmt)
            t2 = datetime.strptime(end_time, fmt)
            if t2 < t1:
                t2 += timedelta(days=1)
            return (t2 - t1).total_seconds() / 3600
        except:
            return 0

    def format_wait_time(hours):
      hr = int(hours)
      mins = int((hours % 1) * 60)
      return f"{hr}h {mins}m"

    def suggest_nearby_junctions(df, source, destination):
      # Get all station codes that appear in the data
      station_codes = df['Station Code'].unique()

      # Find distances from source to all other stations (ignoring direct train requirement)
      source_rows = df[df['Station Code'] == source]
      nearby_station_codes = set()

      for train in source_rows['Train No'].unique():
          train_data = df[df['Train No'] == train].sort_values('Distance')
          if source in train_data['Station Code'].values:
              source_distance = train_data[train_data['Station Code'] == source]['Distance'].values[0]
              train_data['DistanceFromSource'] = abs(train_data['Distance'] - source_distance)
              near_stations = train_data[train_data['DistanceFromSource'] <= 150]
              nearby_station_codes.update(near_stations['Station Code'].values)

      # Now check if these nearby stations have a direct train to the destination
      potential_junctions = []
      for station in nearby_station_codes:
          direct = df[(df['Station Code'] == station) & (df['Destination Station'] == destination)]
          if not direct.empty:
              potential_junctions.append((station, round(direct['Distance'].values[0], 2)))

      if potential_junctions:
          print("\nStations within ~2 hours (~150 km) that have direct train to destination:")
          for junc, dist in potential_junctions:
              print(f"- {junc} ({dist} km approx. from {source})")
      else:
          print("No nearby junctions found with direct train to destination within 2 hours travel.")


    def bfs(start, end, max_depth):
        queue = deque()
        queue.append((start, [], 0))
        visited = set()
        routes = []

        while queue:
            current, path, depth = queue.popleft()
            if current == end:
                routes.append(path)
                continue
            if depth >= max_depth:
                continue
            if current in visited:
                continue
            visited.add(current)
            if current not in graph:
                continue
            for train_no, next_station in graph[current].items():
                seq_info = train_info[train_no]['seq']
                stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
                try:
                    current_idx = stations_in_order.index(current)
                    next_idx = stations_in_order.index(next_station)
                    if next_idx > current_idx:
                        new_path = path + [(train_no, current, next_station)]
                        queue.append((next_station, new_path, depth + 1))
                except ValueError:
                    continue
        return routes

    all_routes = []
    for connections in range(1, max_connections + 1):
        routes = bfs(source, destination, connections)
        all_routes.extend(routes)

    csv_data = []
    for route_num, route in enumerate(all_routes, 1):
        total_trains = len(route)
        total_distance = 0
        total_duration_hours = 0
        route_segments = []

        for segment in route:
            train_no, from_station, to_station = segment
            train_name = train_info[train_no]['name']
            seat_available = train_info[train_no]['seat_availability']

            seq_info = train_info[train_no]['seq']
            for seq, info in seq_info.items():
                if info['station'] == from_station:
                    departure = info['departure']
                    from_distance = float(info['distance'])
                if info['station'] == to_station:
                    arrival = info['arrival']
                    to_distance = float(info['distance'])

            segment_distance = abs(to_distance - from_distance)
            total_distance += segment_distance

             # Calculate segment duration based on distance
            if segment_distance > 1800:
                segment_duration = segment_distance / 58  # Superfast long-distance
            elif segment_distance > 1000:
                segment_duration = segment_distance / 60
            elif segment_distance > 500:
                segment_duration = segment_distance / 55
            elif segment_distance > 300:
                segment_duration = segment_distance / 50
            elif segment_distance > 150:
                segment_duration = segment_distance / 45
            else:
                segment_duration = segment_distance / 38  # Local or short distance
            wait_time = 0
            total_duration_hours += segment_duration
            if route.index(segment) > 0:
                prev_arrival = route_segments[-1]['Arrival Time']
                wait_time = calculate_time_diff(prev_arrival, departure)
                if wait_time < 0:
                    wait_time += 24
                total_duration_hours += wait_time

            route_segments.append({
                'Train Number': train_no,
                'Train Name': train_name,
                'From Station': from_station,
                'Departure Time': departure,
                'To Station': to_station,
                'Arrival Time': arrival,
                'Segment Distance (km)': segment_distance,
                'Segment Duration (hrs)': round(segment_duration, 2),
                'Seat Availability': seat_available,
                'Waiting Time Before Segment (hrs)': round(wait_time, 2)


            })

        total_cost = total_distance * 1
        hours = int(total_duration_hours)
        minutes = int((total_duration_hours % 1) * 60)
        total_duration = f"{hours}h {minutes}m"

        for segment_num, segment in enumerate(route_segments, 1):
            csv_data.append({
                'Route Number': route_num,
                'Total Trains in Route': total_trains,
                'Segment Number': segment_num,
                'Train Number': segment['Train Number'],
                'Train Name': segment['Train Name'],
                'From Station': segment['From Station'],
                'Departure Time': segment['Departure Time'],
                'To Station': segment['To Station'],
                'Arrival Time': segment['Arrival Time'],
                'Segment Distance (km)': segment['Segment Distance (km)'],
                'Segment Duration (hrs)': segment['Segment Duration (hrs)'],
                'Seat Availability': segment['Seat Availability'],
                'Waiting Time Before Segment (hrs)': segment['Waiting Time Before Segment (hrs)'],
                'Total Route Distance (km)': total_distance,
                'Total Route Duration': total_duration,
                'Estimated Cost (₹)': total_cost
            })

    if csv_data:
        routes_df = pd.DataFrame(csv_data)
        columns = [
            'Route Number', 'Total Trains in Route', 'Segment Number',
            'Train Number', 'Train Name', 'From Station', 'Departure Time',
            'To Station', 'Arrival Time', 'Segment Distance (km)',
            'Segment Duration (hrs)', 'Seat Availability', 'Waiting Time Before Segment (hrs)',
            'Total Route Distance (km)', 'Total Route Duration', 'Estimated Cost (₹)'
        ]
        routes_df = routes_df[columns]
        routes_df.to_csv(output_file, index=False)
        print(f"\nSuccessfully saved {len(all_routes)} routes to {output_file}")
        return routes_df
    else:
        print("\nNo valid routes found with the given parameters.")
        return None

def analyze_routes(routes_df):
    unique_routes = routes_df['Route Number'].unique()
    print(f"\nFound {len(unique_routes)} unique routes:")

    for route_num in unique_routes:
        route_data = routes_df[routes_df['Route Number'] == route_num]
        first_row = route_data.iloc[0]
        print(f"\nRoute {route_num}:")
        print(f"- Trains required: {first_row['Total Trains in Route']}")
        print(f"- Total distance: {first_row['Total Route Distance (km)']} km")
        print(f"- Total duration: {first_row['Total Route Duration']}")
        print(f"- Estimated cost: ₹{first_row['Estimated Cost (₹)']}")

        print("  Segments:")
        for _, segment in route_data.iterrows():
            print(f"  {segment['Segment Number']}. {segment['Train Name']} ({segment['Train Number']})")
            print(f"     {segment['From Station']} ({segment['Departure Time']}) → {segment['To Station']} ({segment['Arrival Time']})")
            print(f"     Distance: {segment['Segment Distance (km)']} km | Duration: {segment['Segment Duration (hrs)']} hrs | Seat Available: {segment['Seat Availability']}")

    routes_summary = routes_df.drop_duplicates('Route Number')

    if len(routes_summary) > 1:
        fastest = routes_summary.loc[routes_summary['Total Route Duration'].idxmin()]
        shortest = routes_summary.loc[routes_summary['Total Route Distance (km)'].idxmin()]
        cheapest = routes_summary.loc[routes_summary['Estimated Cost (₹)'].idxmin()]

        print("\nRecommendations:")
        print(f"- Fastest route: Route {fastest['Route Number']} ({fastest['Total Route Duration']})")
        print(f"- Shortest route: Route {shortest['Route Number']} ({shortest['Total Route Distance (km)']} km)")
        print(f"- Cheapest route: Route {cheapest['Route Number']} (₹{cheapest['Estimated Cost (₹)']})")

if __name__ == "__main__":
    main()
# Out:
# === Train Route Finder ===
# Finds connecting routes between any two stations with distance, time, and cost calculations
# C:\Users\Gaurav Nagar\AppData\Local\Temp\ipykernel_12608\552336925.py:12: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Train_details.csv')
# Successfully loaded train schedule data.
#
# Enter station codes (3-4 letter codes like PGT, KOTA, etc.)
#
# Successfully saved 153 routes to PGT_to_KOTA_routes.csv
#
# Analysis of found routes:
#
# Found 153 unique routes:
#
# Route 1:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 0
#
# Route 2:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 1
#
# Route 3:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 4:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 5:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57.16 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18.78 hrs | Seat Available: 0
#
# Route 6:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20.75 hrs | Seat Available: 1
#
# Route 7:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19.97 hrs | Seat Available: 1
#
# Route 8:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41.86 hrs | Seat Available: 0
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11.29 hrs | Seat Available: 1
#
# Route 9:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 0
#
# Route 10:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 1
#
# Route 11:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 12:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 13:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57.16 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18.78 hrs | Seat Available: 0
#
# Route 14:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20.75 hrs | Seat Available: 1
#
# Route 15:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19.97 hrs | Seat Available: 1
#
# Route 16:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41.86 hrs | Seat Available: 0
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11.29 hrs | Seat Available: 1
#
# Route 17:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43.93 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12.65 hrs | Seat Available: 1
#
# Route 18:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43.93 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12.67 hrs | Seat Available: 1
#
# Route 19:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44.05 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17.0 hrs | Seat Available: 1
#
# Route 20:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44.05 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17.69 hrs | Seat Available: 1
#
# Route 21:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42.07 hrs | Seat Available: 0
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5.31 hrs | Seat Available: 1
#
# Route 22:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42.07 hrs | Seat Available: 0
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5.31 hrs | Seat Available: 1
#
# Route 23:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11.96 hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8.24 hrs | Seat Available: 0
#
# Route 24:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20.27 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17.5 hrs | Seat Available: 0
#
# Route 25:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20.27 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17.22 hrs | Seat Available: 1
#
# Route 26:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22.9 hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11.36 hrs | Seat Available: 1
#
# Route 27:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 28:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 29:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 30:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 0
#
# Route 31:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 32:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3.64 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15.11 hrs | Seat Available: 1
#
# Route 33:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3.0 hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20.6 hrs | Seat Available: 1
#
# Route 34:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3.0 hrs | Seat Available: 0
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19.82 hrs | Seat Available: 1
#
# Route 35:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21.58 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11.91 hrs | Seat Available: 1
#
# Route 36:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3.49 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11.16 hrs | Seat Available: 1
#
# Route 37:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8.6 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11.33 hrs | Seat Available: 1
#
# Route 38:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8.6 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11.33 hrs | Seat Available: 1
#
# Route 39:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6.56 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14.27 hrs | Seat Available: 0
#
# Route 40:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6.56 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13.98 hrs | Seat Available: 1
#
# Route 41:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9.48 hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16.71 hrs | Seat Available: 1
#
# Route 42:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4.24 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7.46 hrs | Seat Available: 1
#
# Route 43:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4.24 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7.46 hrs | Seat Available: 1
#
# Route 44:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. ROK INTERCIT (14323)
#      NDLS (10:35:00) → ROK (12:55:00)
#      Distance: 71.0 km | Duration: 1.87 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      ROK (11:20:00) → KOTA (23:50:00)
#      Distance: 528.0 km | Duration: 9.6 hrs | Seat Available: 0
#
# Route 45:
# - Trains required: 3
# - Total distance: 4375.0 km
# - Total duration: 95h 8m
# - Estimated cost: ₹4375.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11.44 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      UHP (22:25:00) → KOTA (23:50:00)
#      Distance: 1103.0 km | Duration: 18.38 hrs | Seat Available: 0
#
# Route 46:
# - Trains required: 3
# - Total distance: 4358.0 km
# - Total duration: 87h 1m
# - Estimated cost: ₹4358.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11.44 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UHP (14:35:00) → KOTA (11:10:00)
#      Distance: 1086.0 km | Duration: 18.1 hrs | Seat Available: 1
#
# Route 47:
# - Trains required: 3
# - Total distance: 3188.0 km
# - Total duration: 90h 51m
# - Estimated cost: ₹3188.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS-SNP 12C (64003)
#      NDLS (05:00:00) → SNP (06:10:00)
#      Distance: 44.0 km | Duration: 1.16 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      SNP (01:56:00) → KOTA (11:10:00)
#      Distance: 501.0 km | Duration: 9.11 hrs | Seat Available: 1
#
# Route 48:
# - Trains required: 3
# - Total distance: 3279.0 km
# - Total duration: 67h 16m
# - Estimated cost: ₹3279.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. GZB-PNP MEMU (64471)
#      NDLS (18:07:00) → PNP (20:20:00)
#      Distance: 89.0 km | Duration: 2.34 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      PNP (01:23:00) → KOTA (11:10:00)
#      Distance: 547.0 km | Duration: 9.95 hrs | Seat Available: 1
#
# Route 49:
# - Trains required: 3
# - Total distance: 3101.0 km
# - Total duration: 77h 47m
# - Estimated cost: ₹3101.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. SSB-BVH-PWL (64908)
#      NDLS (06:30:00) → BVH (07:35:00)
#      Distance: 33.0 km | Duration: 0.87 hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      BVH (13:41:00) → KOTA (20:00:00)
#      Distance: 425.0 km | Duration: 8.5 hrs | Seat Available: 1
#
# Route 50:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 95h 15m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1.29 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1196.0 km | Duration: 19.93 hrs | Seat Available: 1
#
# Route 51:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 28m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1.29 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1149.0 km | Duration: 19.15 hrs | Seat Available: 1
#
# Route 52:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 93h 30m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4.6 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 1038.0 km | Duration: 17.3 hrs | Seat Available: 1
#
# Route 53:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 13m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4.6 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 991.0 km | Duration: 18.02 hrs | Seat Available: 1
#
# Route 54:
# - Trains required: 3
# - Total distance: 4083.0 km
# - Total duration: 92h 59m
# - Estimated cost: ₹4083.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3.11 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1128.0 km | Duration: 18.8 hrs | Seat Available: 1
#
# Route 55:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 92h 12m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3.11 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1081.0 km | Duration: 18.02 hrs | Seat Available: 1
#
# Route 56:
# - Trains required: 3
# - Total distance: 3715.0 km
# - Total duration: 86h 0m
# - Estimated cost: ₹3715.0
#   Segments:
#   1. MAQ MS EXP (16860)
#      PGT (13:45:00) → MS (04:15:00)
#      Distance: 632.0 km | Duration: 11.49 hrs | Seat Available: 1
#   2. SHRADDHA SET (16793)
#      MS (13:00:00) → FD (08:30:00)
#      Distance: 2259.0 km | Duration: 38.95 hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      FD (20:20:00) → KOTA (12:55:00)
#      Distance: 824.0 km | Duration: 14.98 hrs | Seat Available: 1
#
# Route 57:
# - Trains required: 3
# - Total distance: 3412.0 km
# - Total duration: 64h 19m
# - Estimated cost: ₹3412.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41.86 hrs | Seat Available: 0
#   2. JP-SOG PASSA (59706)
#      BKN (14:30:00) → SOG (18:10:00)
#      Distance: 181.0 km | Duration: 4.02 hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SOG (19:55:00) → KOTA (09:50:00)
#      Distance: 803.0 km | Duration: 14.6 hrs | Seat Available: 1
#
# Route 58:
# - Trains required: 3
# - Total distance: 3434.0 km
# - Total duration: 84h 21m
# - Estimated cost: ₹3434.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39.52 hrs | Seat Available: 0
#   2. INDORE BHIND (21125)
#      INDB (20:05:00) → BIX (09:50:00)
#      Distance: 643.0 km | Duration: 11.69 hrs | Seat Available: 0
#   3. BHIND-KOTA P (59822)
#      BIX (18:10:00) → KOTA (09:45:00)
#      Distance: 499.0 km | Duration: 9.98 hrs | Seat Available: 0
#
# Route 59:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 52h 40m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39.52 hrs | Seat Available: 0
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3.5 hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      NAD (14:40:00) → KOTA (19:45:00)
#      Distance: 221.0 km | Duration: 4.91 hrs | Seat Available: 1
#
# Route 60:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 54h 15m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39.52 hrs | Seat Available: 0
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3.5 hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      NAD (16:15:00) → KOTA (22:30:00)
#      Distance: 221.0 km | Duration: 4.91 hrs | Seat Available: 1
#
# Route 61:
# - Trains required: 3
# - Total distance: 2675.0 km
# - Total duration: 53h 45m
# - Estimated cost: ₹2675.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39.52 hrs | Seat Available: 0
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3.11 hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      RTM (13:20:00) → KOTA (19:45:00)
#      Distance: 265.0 km | Duration: 5.89 hrs | Seat Available: 1
#
# Route 62:
# - Trains required: 3
# - Total distance: 2676.0 km
# - Total duration: 55h 17m
# - Estimated cost: ₹2676.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39.52 hrs | Seat Available: 0
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3.11 hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      RTM (14:50:00) → KOTA (22:30:00)
#      Distance: 266.0 km | Duration: 5.91 hrs | Seat Available: 1
#
# Route 63:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 0
#
# Route 64:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9.14 hrs | Seat Available: 1
#
# Route 65:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 66:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9.0 hrs | Seat Available: 1
#
# Route 67:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57.16 hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18.78 hrs | Seat Available: 0
#
# Route 68:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20.75 hrs | Seat Available: 1
#
# Route 69:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48.91 hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19.97 hrs | Seat Available: 1
#
# Route 70:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41.86 hrs | Seat Available: 0
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11.29 hrs | Seat Available: 1
#
# Route 71:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43.93 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12.65 hrs | Seat Available: 1
#
# Route 72:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43.93 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12.67 hrs | Seat Available: 1
#
# Route 73:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44.05 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17.0 hrs | Seat Available: 1
#
# Route 74:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44.05 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17.69 hrs | Seat Available: 1
#
# Route 75:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42.07 hrs | Seat Available: 0
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5.31 hrs | Seat Available: 1
#
# Route 76:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8.72 hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42.07 hrs | Seat Available: 0
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5.31 hrs | Seat Available: 1
#
# Route 77:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11.96 hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8.24 hrs | Seat Available: 0
#
# Route 78:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20.27 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17.5 hrs | Seat Available: 0
#
# Route 79:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20.27 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17.22 hrs | Seat Available: 1
#
# Route 80:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22.9 hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11.36 hrs | Seat Available: 1
#
# Route 81:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 82:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 83:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 84:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 0
#
# Route 85:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6.4 hrs | Seat Available: 1
#
# Route 86:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3.64 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15.11 hrs | Seat Available: 1
#
# Route 87:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3.0 hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20.6 hrs | Seat Available: 1
#
# Route 88:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3.0 hrs | Seat Available: 0
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19.82 hrs | Seat Available: 1
#
# Route 89:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21.58 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11.91 hrs | Seat Available: 1
#
# Route 90:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3.49 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11.16 hrs | Seat Available: 1
#
# Route 91:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8.6 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11.33 hrs | Seat Available: 1
#
# Route 92:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8.6 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11.33 hrs | Seat Available: 1
#
# Route 93:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6.56 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14.27 hrs | Seat Available: 0
#
# Route 94:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6.56 hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13.98 hrs | Seat Available: 1
#
# Route 95:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9.48 hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16.71 hrs | Seat Available: 1
#
# Route 96:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4.24 hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7.46 hrs | Seat Available: 1
#
# Route 97:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4.24 hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7.46 hrs | Seat Available: 1
#
# Route 98:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. ROK INTERCIT (14323)
#      NDLS (10:35:00) → ROK (12:55:00)
#      Distance: 71.0 km | Duration: 1.87 hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      ROK (11:20:00) → KOTA (23:50:00)
#      Distance: 528.0 km | Duration: 9.6 hrs | Seat Available: 0
#
# Route 99:
# - Trains required: 3
# - Total distance: 4375.0 km
# - Total duration: 95h 8m
# - Estimated cost: ₹4375.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45.57 hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
# ...
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11.96 hrs | Seat Available: 1
#   3. BIN-GWL PASS (51884)
#      GWL (08:30:00) → BINA (17:45:00)
#      Distance: 345.0 km | Duration: 6.9 hrs | Seat Available: 1
#   4. BINA-KOTA PA (51612)
#      BINA (10:00:00) → KOTA (18:50:00)
#      Distance: 303.0 km | Duration: 6.06 hrs | Seat Available: 1
#
# Route 131:
# - Trains required: 4
# - Total distance: 4753.0 km
# - Total duration: 124h 9m
# - Estimated cost: ₹4753.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17.31 hrs | Seat Available: 0
#   3. HSR-JIND PAS (54044)
#      HSR (05:00:00) → JIND (14:50:00)
#      Distance: 327.0 km | Duration: 6.54 hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JIND (10:27:00) → KOTA (23:50:00)
#      Distance: 585.0 km | Duration: 10.64 hrs | Seat Available: 0
#
# Route 132:
# - Trains required: 4
# - Total distance: 4711.0 km
# - Total duration: 102h 57m
# - Estimated cost: ₹4711.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17.31 hrs | Seat Available: 0
#   3. DUI JHL HSR (54631)
#      HSR (18:10:00) → DUI (21:35:00)
#      Distance: 147.0 km | Duration: 3.87 hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      DUI (07:00:00) → KOTA (23:50:00)
#      Distance: 723.0 km | Duration: 13.15 hrs | Seat Available: 0
#
# Route 133:
# - Trains required: 4
# - Total distance: 4784.0 km
# - Total duration: 119h 20m
# - Estimated cost: ₹4784.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24.97 hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3.76 hrs | Seat Available: 0
#   4. NMH - KOTA E (29019)
#      NMH (14:40:00) → KOTA (18:45:00)
#      Distance: 228.0 km | Duration: 5.07 hrs | Seat Available: 1
#
# Route 134:
# - Trains required: 4
# - Total distance: 4783.0 km
# - Total duration: 103h 9m
# - Estimated cost: ₹4783.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24.97 hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3.76 hrs | Seat Available: 0
#   4. NMH-KOTA FAS (59834)
#      NMH (22:30:00) → KOTA (04:45:00)
#      Distance: 227.0 km | Duration: 5.04 hrs | Seat Available: 1
#
# Route 135:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 126h 9m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. KOTA JANSHTB (12060)
#      SWM (18:07:00) → KOTA (20:00:00)
#      Distance: 108.0 km | Duration: 2.84 hrs | Seat Available: 1
#
# Route 136:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. PNBE- KOTA (13237)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2.84 hrs | Seat Available: 1
#
# Route 137:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. PNBE-KOTA EX (13239)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2.84 hrs | Seat Available: 1
#
# Route 138:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 105h 21m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. SVDK-KOTA WE (19804)
#      SWM (21:20:00) → KOTA (23:50:00)
#      Distance: 107.0 km | Duration: 2.82 hrs | Seat Available: 0
#
# Route 139:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 117h 28m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. UHP-KOTA WEE (19806)
#      SWM (09:27:00) → KOTA (11:10:00)
#      Distance: 107.0 km | Duration: 2.82 hrs | Seat Available: 1
#
# Route 140:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 111h 12m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. JP-KOTA EXP (19808)
#      SWM (03:10:00) → KOTA (05:20:00)
#      Distance: 108.0 km | Duration: 2.84 hrs | Seat Available: 1
#
# Route 141:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 115h 57m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. KOTA-HMH -KO (22982)
#      SWM (07:55:00) → KOTA (09:50:00)
#      Distance: 108.0 km | Duration: 2.84 hrs | Seat Available: 1
#
# Route 142:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 122h 1m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 0
#   4. JAB-KOTA PAS (59814)
#      SWM (14:00:00) → KOTA (17:15:00)
#      Distance: 107.0 km | Duration: 2.82 hrs | Seat Available: 0
#
# Route 143:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 127h 55m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1.63 hrs | Seat Available: 1
#   4. KOTA JANSHTB (12060)
#      BTE (15:50:00) → KOTA (20:00:00)
#      Distance: 287.0 km | Duration: 6.38 hrs | Seat Available: 1
#
# Route 144:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 120h 18m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1.63 hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 286.0 km | Duration: 6.36 hrs | Seat Available: 1
#
# Route 145:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 120h 20m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1.63 hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 287.0 km | Duration: 6.38 hrs | Seat Available: 1
#
# Route 146:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 130h 42m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1.63 hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      BTE (18:39:00) → KOTA (23:50:00)
#      Distance: 286.0 km | Duration: 6.36 hrs | Seat Available: 0
#
# Route 147:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 118h 58m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49.81 hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12.76 hrs | Seat Available: 1
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1.63 hrs | Seat Available: 1
#   4. UHP-KOTA WEE (19806)
#      BTE (06:55:00) → KOTA (11:10:00)
#      Distance: 286.0 km | Duration: 6.36 hrs | Seat Available: 1
#
# Route 148:
# - Trains required: 4
# - Total distance: 4593.0 km
# - Total duration: 113h 20m
# - Estimated cost: ₹4593.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SDAH BUI EXP (13105)
#      BJU (23:55:00) → BUI (06:10:00)
#      Distance: 212.0 km | Duration: 4.71 hrs | Seat Available: 1
#   3. BUI - SHG  P (55137)
#      BUI (05:25:00) → SHG (11:15:00)
#      Distance: 167.0 km | Duration: 3.71 hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      SHG (18:18:00) → KOTA (12:55:00)
#      Distance: 929.0 km | Duration: 16.89 hrs | Seat Available: 1
#
# Route 149:
# - Trains required: 4
# - Total distance: 5154.0 km
# - Total duration: 119h 41m
# - Estimated cost: ₹5154.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18.17 hrs | Seat Available: 1
#   3. DELHI JIND P (54033)
#      DLI (17:25:00) → NRW (22:25:00)
#      Distance: 160.0 km | Duration: 3.56 hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      NRW (09:30:00) → KOTA (23:50:00)
#      Distance: 619.0 km | Duration: 11.25 hrs | Seat Available: 0
#
# Route 150:
# - Trains required: 4
# - Total distance: 5231.0 km
# - Total duration: 119h 35m
# - Estimated cost: ₹5231.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18.17 hrs | Seat Available: 1
#   3. DELHI JIND J (54035)
#      DLI (15:40:00) → JHL (21:40:00)
#      Distance: 199.0 km | Duration: 4.42 hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JHL (08:50:00) → KOTA (23:50:00)
#      Distance: 657.0 km | Duration: 11.95 hrs | Seat Available: 0
#
# Route 151:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18.17 hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4.51 hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8.04 hrs | Seat Available: 1
#
# Route 152:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56.64 hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18.17 hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4.51 hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8.04 hrs | Seat Available: 1
#
# Route 153:
# - Trains required: 4
# - Total distance: 4536.0 km
# - Total duration: 120h 51m
# - Estimated cost: ₹4536.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45.43 hrs | Seat Available: 1
#   2. HW BL SUP EX (12912)
#      NZM (23:35:00) → BL (18:20:00)
#      Distance: 1176.0 km | Duration: 19.6 hrs | Seat Available: 1
#   3. BL-DHD INTER (12929)
#      BL (07:15:00) → DHD (13:25:00)
#      Distance: 344.0 km | Duration: 6.88 hrs | Seat Available: 1
#   4. BRC-KOTA PAR (59831)
#      DHD (11:25:00) → KOTA (22:30:00)
#      Distance: 381.0 km | Duration: 7.62 hrs | Seat Available: 1
#
# Recommendations:
# - Fastest route: Route 44 (100h 17m)
# - Shortest route: Route 59 (2646.0 km)
# - Cheapest route: Route 59 (₹2646.0)
#
# Detailed routes saved to: PGT_to_KOTA_routes.csv
#
# === Nearby 2-hour junctions to catch train to destination ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 341
#     338         print(f"- Cheapest route: Route {cheapest['Route Number']} (₹{cheapest['Estimated Cost (₹)']})")
#     340 if __name__ == "__main__":
# --> 341     main()
#
# Cell In[3], line 59, in main()
#      57 print(f"\nDetailed routes saved to: {output_file}")
#      58 print("\n=== Nearby 2-hour junctions to catch train to destination ===")
# ---> 59 suggest_nearby_junctions(df, source, destination)
#
# NameError: name 'suggest_nearby_junctions' is not defined

# %%
# Out:
# === Train Route Finder ===
# Finds connecting routes between any two stations with distance, time, and cost calculations
# <ipython-input-10-fed23eee661e>:12: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Train_details.csv')
# Successfully loaded train schedule data.
#
# Enter station codes (3-4 letter codes like PGT, KOTA, etc.)
# Enter origin station code: PGT
# Enter destination station code: KOTA
# Enter maximum number of connections (1-4 recommended): 4
#
# Successfully saved 153 routes to PGT_to_KOTA_routes.csv
#
# Analysis of found routes:
#
# Found 153 unique routes:
#
# Route 1:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 2:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 3:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 4:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 5:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 6:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 7:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 8:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 9:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 10:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 11:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 12:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 13:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 14:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 15:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 16:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 17:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12h 39m hrs | Seat Available: 1
#
# Route 18:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12h 40m hrs | Seat Available: 1
#
# Route 19:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17h 0m hrs | Seat Available: 1
#
# Route 20:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17h 41m hrs | Seat Available: 1
#
# Route 21:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 22:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 23:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 0
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8h 14m hrs | Seat Available: 1
#
# Route 24:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17h 30m hrs | Seat Available: 1
#
# Route 25:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17h 12m hrs | Seat Available: 1
#
# Route 26:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22h 53m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11h 21m hrs | Seat Available: 1
#
# Route 27:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 28:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 29:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 30:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 31:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 32:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3h 38m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15h 6m hrs | Seat Available: 1
#
# Route 33:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20h 36m hrs | Seat Available: 1
#
# Route 34:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19h 48m hrs | Seat Available: 1
#
# Route 35:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21h 34m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11h 54m hrs | Seat Available: 1
#
# Route 36:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3h 29m hrs | Seat Available: 0
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11h 9m hrs | Seat Available: 1
#
# Route 37:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 38:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 39:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14h 16m hrs | Seat Available: 1
#
# Route 40:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13h 58m hrs | Seat Available: 1
#
# Route 41:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9h 28m hrs | Seat Available: 0
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16h 42m hrs | Seat Available: 1
#
# Route 42:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 43:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 44:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. ROK INTERCIT (14323)
#      NDLS (10:35:00) → ROK (12:55:00)
#      Distance: 71.0 km | Duration: 1h 52m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      ROK (11:20:00) → KOTA (23:50:00)
#      Distance: 528.0 km | Duration: 9h 35m hrs | Seat Available: 1
#
# Route 45:
# - Trains required: 3
# - Total distance: 4375.0 km
# - Total duration: 95h 8m
# - Estimated cost: ₹4375.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11h 26m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      UHP (22:25:00) → KOTA (23:50:00)
#      Distance: 1103.0 km | Duration: 18h 22m hrs | Seat Available: 1
#
# Route 46:
# - Trains required: 3
# - Total distance: 4358.0 km
# - Total duration: 87h 1m
# - Estimated cost: ₹4358.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. KOTA-UHP WEE (19805)
#      NDLS (23:20:00) → UHP (12:15:00)
#      Distance: 629.0 km | Duration: 11h 26m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UHP (14:35:00) → KOTA (11:10:00)
#      Distance: 1086.0 km | Duration: 18h 6m hrs | Seat Available: 1
#
# Route 47:
# - Trains required: 3
# - Total distance: 3188.0 km
# - Total duration: 90h 51m
# - Estimated cost: ₹3188.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-SNP 12C (64003)
#      NDLS (05:00:00) → SNP (06:10:00)
#      Distance: 44.0 km | Duration: 1h 9m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      SNP (01:56:00) → KOTA (11:10:00)
#      Distance: 501.0 km | Duration: 9h 6m hrs | Seat Available: 1
#
# Route 48:
# - Trains required: 3
# - Total distance: 3279.0 km
# - Total duration: 67h 16m
# - Estimated cost: ₹3279.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. GZB-PNP MEMU (64471)
#      NDLS (18:07:00) → PNP (20:20:00)
#      Distance: 89.0 km | Duration: 2h 20m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      PNP (01:23:00) → KOTA (11:10:00)
#      Distance: 547.0 km | Duration: 9h 56m hrs | Seat Available: 1
#
# Route 49:
# - Trains required: 3
# - Total distance: 3101.0 km
# - Total duration: 77h 47m
# - Estimated cost: ₹3101.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SSB-BVH-PWL (64908)
#      NDLS (06:30:00) → BVH (07:35:00)
#      Distance: 33.0 km | Duration: 0h 52m hrs | Seat Available: 1
#   3. KOTA JANSHTB (12060)
#      BVH (13:41:00) → KOTA (20:00:00)
#      Distance: 425.0 km | Duration: 8h 30m hrs | Seat Available: 1
#
# Route 50:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 95h 15m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1h 17m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1196.0 km | Duration: 19h 56m hrs | Seat Available: 1
#
# Route 51:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 28m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-ARA MEM (63213)
#      PNBE (17:15:00) → ARA (18:50:00)
#      Distance: 49.0 km | Duration: 1h 17m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      ARA (12:32:00) → KOTA (12:55:00)
#      Distance: 1149.0 km | Duration: 19h 8m hrs | Seat Available: 1
#
# Route 52:
# - Trains required: 3
# - Total distance: 4082.0 km
# - Total duration: 93h 30m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 1038.0 km | Duration: 17h 18m hrs | Seat Available: 1
#
# Route 53:
# - Trains required: 3
# - Total distance: 4035.0 km
# - Total duration: 94h 13m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-MGS MEM (63225)
#      PNBE (12:05:00) → MGS (19:15:00)
#      Distance: 207.0 km | Duration: 4h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      MGS (15:42:00) → KOTA (12:55:00)
#      Distance: 991.0 km | Duration: 18h 1m hrs | Seat Available: 1
#
# Route 54:
# - Trains required: 3
# - Total distance: 4083.0 km
# - Total duration: 92h 59m
# - Estimated cost: ₹4083.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1128.0 km | Duration: 18h 48m hrs | Seat Available: 1
#
# Route 55:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 92h 12m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. FUT - BXR ME (63261)
#      PNBE (18:30:00) → BXR (23:50:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 0
#   3. PNBE-KOTA EX (13239)
#      BXR (13:20:00) → KOTA (12:55:00)
#      Distance: 1081.0 km | Duration: 18h 0m hrs | Seat Available: 1
#
# Route 56:
# - Trains required: 3
# - Total distance: 3715.0 km
# - Total duration: 86h 0m
# - Estimated cost: ₹3715.0
#   Segments:
#   1. MAQ MS EXP (16860)
#      PGT (13:45:00) → MS (04:15:00)
#      Distance: 632.0 km | Duration: 11h 29m hrs | Seat Available: 1
#   2. SHRADDHA SET (16793)
#      MS (13:00:00) → FD (08:30:00)
#      Distance: 2259.0 km | Duration: 38h 56m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      FD (20:20:00) → KOTA (12:55:00)
#      Distance: 824.0 km | Duration: 14h 58m hrs | Seat Available: 1
#
# Route 57:
# - Trains required: 3
# - Total distance: 3412.0 km
# - Total duration: 64h 19m
# - Estimated cost: ₹3412.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. JP-SOG PASSA (59706)
#      BKN (14:30:00) → SOG (18:10:00)
#      Distance: 181.0 km | Duration: 4h 1m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      SOG (19:55:00) → KOTA (09:50:00)
#      Distance: 803.0 km | Duration: 14h 35m hrs | Seat Available: 1
#
# Route 58:
# - Trains required: 3
# - Total distance: 3434.0 km
# - Total duration: 84h 21m
# - Estimated cost: ₹3434.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDORE BHIND (21125)
#      INDB (20:05:00) → BIX (09:50:00)
#      Distance: 643.0 km | Duration: 11h 41m hrs | Seat Available: 1
#   3. BHIND-KOTA P (59822)
#      BIX (18:10:00) → KOTA (09:45:00)
#      Distance: 499.0 km | Duration: 9h 58m hrs | Seat Available: 1
#
# Route 59:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 52h 40m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3h 30m hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      NAD (14:40:00) → KOTA (19:45:00)
#      Distance: 221.0 km | Duration: 4h 54m hrs | Seat Available: 1
#
# Route 60:
# - Trains required: 3
# - Total distance: 2646.0 km
# - Total duration: 54h 15m
# - Estimated cost: ₹2646.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. INDB - NAD P (59388)
#      INDB (08:05:00) → NAD (12:45:00)
#      Distance: 133.0 km | Duration: 3h 30m hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      NAD (16:15:00) → KOTA (22:30:00)
#      Distance: 221.0 km | Duration: 4h 54m hrs | Seat Available: 1
#
# Route 61:
# - Trains required: 3
# - Total distance: 2675.0 km
# - Total duration: 53h 45m
# - Estimated cost: ₹2675.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. RTM-KOTA PAS (59803)
#      RTM (13:20:00) → KOTA (19:45:00)
#      Distance: 265.0 km | Duration: 5h 53m hrs | Seat Available: 1
#
# Route 62:
# - Trains required: 3
# - Total distance: 2676.0 km
# - Total duration: 55h 17m
# - Estimated cost: ₹2676.0
#   Segments:
#   1. AHILYANAGARI (22646)
#      PGT (14:05:00) → INDB (05:15:00)
#      Distance: 2292.0 km | Duration: 39h 31m hrs | Seat Available: 1
#   2. DADN RTM DEM (79305)
#      INDB (08:45:00) → RTM (11:35:00)
#      Distance: 118.0 km | Duration: 3h 6m hrs | Seat Available: 1
#   3. BRC-KOTA PAR (59831)
#      RTM (14:50:00) → KOTA (22:30:00)
#      Distance: 266.0 km | Duration: 5h 54m hrs | Seat Available: 1
#
# Route 63:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 55h 12m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      NDLS (14:15:00) → KOTA (23:50:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 64:
# - Trains required: 2
# - Total distance: 3100.0 km
# - Total duration: 68h 37m
# - Estimated cost: ₹3100.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NDLS (03:40:00) → KOTA (11:10:00)
#      Distance: 457.0 km | Duration: 9h 8m hrs | Seat Available: 1
#
# Route 65:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 74h 30m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. KOTA JANSHTB (12060)
#      NZM (13:15:00) → KOTA (20:00:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 66:
# - Trains required: 2
# - Total distance: 3085.0 km
# - Total duration: 65h 10m
# - Estimated cost: ₹3085.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. UHP-KOTA WEE (19806)
#      NZM (03:55:00) → KOTA (11:10:00)
#      Distance: 450.0 km | Duration: 9h 0m hrs | Seat Available: 1
#
# Route 67:
# - Trains required: 2
# - Total distance: 4442.0 km
# - Total duration: 82h 31m
# - Estimated cost: ₹4442.0
#   Segments:
#   1. CAPE-SVDK HI (16317)
#      PGT (23:50:00) → SVDK (15:20:00)
#      Distance: 3315.0 km | Duration: 57h 9m hrs | Seat Available: 1
#   2. SVDK-KOTA WE (19804)
#      SVDK (21:55:00) → KOTA (23:50:00)
#      Distance: 1127.0 km | Duration: 18h 47m hrs | Seat Available: 1
#
# Route 68:
# - Trains required: 2
# - Total distance: 4082.0 km
# - Total duration: 71h 39m
# - Estimated cost: ₹4082.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE- KOTA (13237)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1245.0 km | Duration: 20h 45m hrs | Seat Available: 1
#
# Route 69:
# - Trains required: 2
# - Total distance: 4035.0 km
# - Total duration: 70h 52m
# - Estimated cost: ₹4035.0
#   Segments:
#   1. ERS PATNA EX (16359)
#      PGT (02:05:00) → PNBE (09:50:00)
#      Distance: 2837.0 km | Duration: 48h 54m hrs | Seat Available: 0
#   2. PNBE-KOTA EX (13239)
#      PNBE (11:50:00) → KOTA (12:55:00)
#      Distance: 1198.0 km | Duration: 19h 57m hrs | Seat Available: 1
#
# Route 70:
# - Trains required: 2
# - Total distance: 3049.0 km
# - Total duration: 63h 49m
# - Estimated cost: ₹3049.0
#   Segments:
#   1. CBE BKN AC S (22476)
#      PGT (16:20:00) → BKN (12:25:00)
#      Distance: 2428.0 km | Duration: 41h 51m hrs | Seat Available: 1
#   2. KOTA-HMH -KO (22982)
#      BKN (23:05:00) → KOTA (09:50:00)
#      Distance: 621.0 km | Duration: 11h 17m hrs | Seat Available: 1
#
# Route 71:
# - Trains required: 3
# - Total distance: 3680.0 km
# - Total duration: 81h 43m
# - Estimated cost: ₹3680.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 696.0 km | Duration: 12h 39m hrs | Seat Available: 1
#
# Route 72:
# - Trains required: 3
# - Total distance: 3681.0 km
# - Total duration: 81h 44m
# - Estimated cost: ₹3681.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-LKO EXPR (12539)
#      YPR (10:50:00) → LKO (08:50:00)
#      Distance: 2548.0 km | Duration: 43h 55m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      LKO (23:55:00) → KOTA (12:55:00)
#      Distance: 697.0 km | Duration: 12h 40m hrs | Seat Available: 1
#
# Route 73:
# - Trains required: 3
# - Total distance: 4011.0 km
# - Total duration: 75h 21m
# - Estimated cost: ₹4011.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 1020.0 km | Duration: 17h 0m hrs | Seat Available: 1
#
# Route 74:
# - Trains required: 3
# - Total distance: 3964.0 km
# - Total duration: 76h 2m
# - Estimated cost: ₹3964.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. MYS-BSB BI-W (16229)
#      YPR (10:25:00) → BSB (12:00:00)
#      Distance: 2555.0 km | Duration: 44h 3m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      BSB (16:40:00) → KOTA (12:55:00)
#      Distance: 973.0 km | Duration: 17h 41m hrs | Seat Available: 1
#
# Route 75:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 76h 1m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. JP-KOTA EXP (19808)
#      JP (00:30:00) → KOTA (05:20:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 76:
# - Trains required: 3
# - Total distance: 3115.0 km
# - Total duration: 81h 11m
# - Estimated cost: ₹3115.0
#   Segments:
#   1. KCVL-YPR EXP (12258)
#      PGT (00:15:00) → YPR (09:30:00)
#      Distance: 436.0 km | Duration: 8h 43m hrs | Seat Available: 1
#   2. YPR-JP WEEKL (82653)
#      YPR (11:30:00) → JP (06:35:00)
#      Distance: 2440.0 km | Duration: 42h 4m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      JP (05:40:00) → KOTA (09:50:00)
#      Distance: 239.0 km | Duration: 5h 18m hrs | Seat Available: 1
#
# Route 77:
# - Trains required: 3
# - Total distance: 3959.0 km
# - Total duration: 107h 40m
# - Estimated cost: ₹3959.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 0
#   3. BHIND-KOTA P (59822)
#      GWL (20:50:00) → KOTA (09:45:00)
#      Distance: 412.0 km | Duration: 8h 14m hrs | Seat Available: 1
#
# Route 78:
# - Trains required: 3
# - Total distance: 5155.0 km
# - Total duration: 122h 9m
# - Estimated cost: ₹5155.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      JAT (23:45:00) → KOTA (23:50:00)
#      Distance: 1050.0 km | Duration: 17h 30m hrs | Seat Available: 1
#
# Route 79:
# - Trains required: 3
# - Total distance: 5138.0 km
# - Total duration: 114h 12m
# - Estimated cost: ₹5138.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. MOURDHWAJ EX (12491)
#      GKP (14:00:00) → JAT (11:50:00)
#      Distance: 1216.0 km | Duration: 20h 15m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      JAT (16:05:00) → KOTA (11:10:00)
#      Distance: 1033.0 km | Duration: 17h 12m hrs | Seat Available: 1
#
# Route 80:
# - Trains required: 3
# - Total distance: 4888.0 km
# - Total duration: 110h 27m
# - Estimated cost: ₹4888.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. AVADH ASSAM (15909)
#      GKP (23:55:00) → LGH (04:30:00)
#      Distance: 1374.0 km | Duration: 22h 53m hrs | Seat Available: 1
#   3. KOTA-HMH -KO (22982)
#      LGH (22:18:00) → KOTA (09:50:00)
#      Distance: 625.0 km | Duration: 11h 21m hrs | Seat Available: 1
#
# Route 81:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 103h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KOTA JANSHTB (12060)
#      MTJ (15:20:00) → KOTA (20:00:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 82:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. PNBE- KOTA (13237)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 83:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 96h 23m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. PNBE-KOTA EX (13239)
#      MTJ (07:45:00) → KOTA (12:55:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 84:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 106h 48m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. SVDK-KOTA WE (19804)
#      MTJ (18:10:00) → KOTA (23:50:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 85:
# - Trains required: 3
# - Total distance: 3911.0 km
# - Total duration: 94h 58m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. UHP-KOTA WEE (19806)
#      MTJ (06:20:00) → KOTA (11:10:00)
#      Distance: 320.0 km | Duration: 6h 24m hrs | Seat Available: 1
#
# Route 86:
# - Trains required: 3
# - Total distance: 3884.0 km
# - Total duration: 91h 29m
# - Estimated cost: ₹3884.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GKP-AY PASSE (55001)
#      GKP (07:40:00) → AY (13:15:00)
#      Distance: 164.0 km | Duration: 3h 38m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AY (19:51:00) → KOTA (12:55:00)
#      Distance: 831.0 km | Duration: 15h 6m hrs | Seat Available: 1
#
# Route 87:
# - Trains required: 3
# - Total distance: 4635.0 km
# - Total duration: 89h 3m
# - Estimated cost: ₹4635.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1236.0 km | Duration: 20h 36m hrs | Seat Available: 1
#
# Route 88:
# - Trains required: 3
# - Total distance: 4588.0 km
# - Total duration: 88h 16m
# - Estimated cost: ₹4588.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SHC-DNR JANH (13205)
#      BJU (01:50:00) → DNR (06:15:00)
#      Distance: 114.0 km | Duration: 3h 0m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      DNR (12:04:00) → KOTA (12:55:00)
#      Distance: 1189.0 km | Duration: 19h 48m hrs | Seat Available: 1
#
# Route 89:
# - Trains required: 3
# - Total distance: 5235.0 km
# - Total duration: 112h 17m
# - Estimated cost: ₹5235.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. MFP-UMB EXPR (14523)
#      BJU (05:00:00) → UMB (07:55:00)
#      Distance: 1295.0 km | Duration: 21h 34m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      UMB (23:55:00) → KOTA (11:10:00)
#      Distance: 655.0 km | Duration: 11h 54m hrs | Seat Available: 1
#
# Route 90:
# - Trains required: 3
# - Total distance: 3414.0 km
# - Total duration: 91h 1m
# - Estimated cost: ₹3414.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. MTJ-KKDE EXP (11901)
#      NDLS (08:45:00) → KKDE (12:40:00)
#      Distance: 157.0 km | Duration: 3h 29m hrs | Seat Available: 0
#   3. UHP-KOTA WEE (19806)
#      KKDE (00:28:00) → KOTA (11:10:00)
#      Distance: 614.0 km | Duration: 11h 9m hrs | Seat Available: 1
#
# Route 91:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 92:
# - Trains required: 3
# - Total distance: 3696.0 km
# - Total duration: 72h 19m
# - Estimated cost: ₹3696.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS CNB SHA (12034)
#      NDLS (15:50:00) → CNB (20:45:00)
#      Distance: 430.0 km | Duration: 8h 35m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      CNB (01:30:00) → KOTA (12:55:00)
#      Distance: 623.0 km | Duration: 11h 19m hrs | Seat Available: 1
#
# Route 93:
# - Trains required: 3
# - Total distance: 3756.0 km
# - Total duration: 100h 29m
# - Estimated cost: ₹3756.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. SVDK-KOTA WE (19804)
#      LDH (05:15:00) → KOTA (23:50:00)
#      Distance: 785.0 km | Duration: 14h 16m hrs | Seat Available: 1
#
# Route 94:
# - Trains required: 3
# - Total distance: 3740.0 km
# - Total duration: 92h 46m
# - Estimated cost: ₹3740.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NDLS-LDH SHA (12037)
#      NDLS (07:00:00) → LDH (12:25:00)
#      Distance: 328.0 km | Duration: 6h 33m hrs | Seat Available: 1
#   3. UHP-KOTA WEE (19806)
#      LDH (21:50:00) → KOTA (11:10:00)
#      Distance: 769.0 km | Duration: 13h 58m hrs | Seat Available: 1
#
# Route 95:
# - Trains required: 3
# - Total distance: 4036.0 km
# - Total duration: 114h 40m
# - Estimated cost: ₹4036.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. NED SGNR EXP (12485)
#      NDLS (13:30:00) → SGNR (22:30:00)
#      Distance: 474.0 km | Duration: 9h 28m hrs | Seat Available: 0
#   3. KOTA-HMH -KO (22982)
#      SGNR (17:40:00) → KOTA (09:50:00)
#      Distance: 919.0 km | Duration: 16h 42m hrs | Seat Available: 1
#
# Route 96:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE- KOTA (13237)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 97:
# - Trains required: 3
# - Total distance: 3207.0 km
# - Total duration: 69h 6m
# - Estimated cost: ₹3207.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 45h 34m hrs | Seat Available: 1
#   2. AGC INTERCIT (14212)
#      NDLS (17:35:00) → AGC (22:05:00)
#      Distance: 191.0 km | Duration: 4h 14m hrs | Seat Available: 1
#   3. PNBE-KOTA EX (13239)
#      AGC (06:05:00) → KOTA (12:55:00)
#      Distance: 373.0 km | Duration: 7h 27m hrs | Seat Available: 1
#
# Route 98:
# - Trains required: 3
# - Total distance: 3242.0 km
# - Total duration: 100h 17m
# - Estimated cost: ₹3242.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
# ...
#      JP (06:40:00) → BXN (12:55:00)
#      Distance: 268.0 km | Duration: 5h 57m hrs | Seat Available: 0
#   4. JAB-KOTA PAS (59814)
#      BXN (10:50:00) → KOTA (17:15:00)
#      Distance: 244.0 km | Duration: 5h 25m hrs | Seat Available: 1
#
# Route 130:
# - Trains required: 4
# - Total distance: 4195.0 km
# - Total duration: 116h 19m
# - Estimated cost: ₹4195.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. BARAUNI-GWL (11123)
#      GKP (05:05:00) → GWL (20:55:00)
#      Distance: 658.0 km | Duration: 11h 57m hrs | Seat Available: 0
#   3. BIN-GWL PASS (51884)
#      GWL (08:30:00) → BINA (17:45:00)
#      Distance: 345.0 km | Duration: 6h 54m hrs | Seat Available: 1
#   4. BINA-KOTA PA (51612)
#      BINA (10:00:00) → KOTA (18:50:00)
#      Distance: 303.0 km | Duration: 6h 3m hrs | Seat Available: 1
#
# Route 131:
# - Trains required: 4
# - Total distance: 4753.0 km
# - Total duration: 124h 9m
# - Estimated cost: ₹4753.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17h 18m hrs | Seat Available: 0
#   3. HSR-JIND PAS (54044)
#      HSR (05:00:00) → JIND (14:50:00)
#      Distance: 327.0 km | Duration: 6h 32m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JIND (10:27:00) → KOTA (23:50:00)
#      Distance: 585.0 km | Duration: 10h 38m hrs | Seat Available: 1
#
# Route 132:
# - Trains required: 4
# - Total distance: 4711.0 km
# - Total duration: 102h 57m
# - Estimated cost: ₹4711.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. GORAKHDHAM E (12555)
#      GKP (16:35:00) → HSR (10:00:00)
#      Distance: 952.0 km | Duration: 17h 18m hrs | Seat Available: 0
#   3. DUI JHL HSR (54631)
#      HSR (18:10:00) → DUI (21:35:00)
#      Distance: 147.0 km | Duration: 3h 52m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      DUI (07:00:00) → KOTA (23:50:00)
#      Distance: 723.0 km | Duration: 13h 8m hrs | Seat Available: 1
#
# Route 133:
# - Trains required: 4
# - Total distance: 4784.0 km
# - Total duration: 119h 20m
# - Estimated cost: ₹4784.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24h 57m hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3h 45m hrs | Seat Available: 1
#   4. NMH - KOTA E (29019)
#      NMH (14:40:00) → KOTA (18:45:00)
#      Distance: 228.0 km | Duration: 5h 3m hrs | Seat Available: 1
#
# Route 134:
# - Trains required: 4
# - Total distance: 4783.0 km
# - Total duration: 103h 9m
# - Estimated cost: ₹4783.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. NJP UDZ EXPR (19602)
#      GKP (22:10:00) → UDZ (03:55:00)
#      Distance: 1498.0 km | Duration: 24h 57m hrs | Seat Available: 1
#   3. UDZ-NMH PASS (59836)
#      UDZ (14:15:00) → NMH (20:05:00)
#      Distance: 169.0 km | Duration: 3h 45m hrs | Seat Available: 1
#   4. NMH-KOTA FAS (59834)
#      NMH (22:30:00) → KOTA (04:45:00)
#      Distance: 227.0 km | Duration: 5h 2m hrs | Seat Available: 1
#
# Route 135:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 126h 9m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. KOTA JANSHTB (12060)
#      SWM (18:07:00) → KOTA (20:00:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 136:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 137:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 119h 2m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      SWM (11:00:00) → KOTA (12:55:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 138:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 105h 21m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      SWM (21:20:00) → KOTA (23:50:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 139:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 117h 28m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. UHP-KOTA WEE (19806)
#      SWM (09:27:00) → KOTA (11:10:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 140:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 111h 12m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. JP-KOTA EXP (19808)
#      SWM (03:10:00) → KOTA (05:20:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 141:
# - Trains required: 4
# - Total distance: 3911.0 km
# - Total duration: 115h 57m
# - Estimated cost: ₹3911.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. KOTA-HMH -KO (22982)
#      SWM (07:55:00) → KOTA (09:50:00)
#      Distance: 108.0 km | Duration: 2h 50m hrs | Seat Available: 1
#
# Route 142:
# - Trains required: 4
# - Total distance: 3910.0 km
# - Total duration: 122h 1m
# - Estimated cost: ₹3910.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. MTJ-SWM PASS (54794)
#      MTJ (14:00:00) → SWM (19:45:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   4. JAB-KOTA PAS (59814)
#      SWM (14:00:00) → KOTA (17:15:00)
#      Distance: 107.0 km | Duration: 2h 48m hrs | Seat Available: 1
#
# Route 143:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 127h 55m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. KOTA JANSHTB (12060)
#      BTE (15:50:00) → KOTA (20:00:00)
#      Distance: 287.0 km | Duration: 6h 22m hrs | Seat Available: 1
#
# Route 144:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 120h 18m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 145:
# - Trains required: 4
# - Total distance: 3940.0 km
# - Total duration: 120h 20m
# - Estimated cost: ₹3940.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      BTE (08:15:00) → KOTA (12:55:00)
#      Distance: 287.0 km | Duration: 6h 22m hrs | Seat Available: 1
#
# Route 146:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 130h 42m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      BTE (18:39:00) → KOTA (23:50:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 147:
# - Trains required: 4
# - Total distance: 3939.0 km
# - Total duration: 118h 58m
# - Estimated cost: ₹3939.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 49h 48m hrs | Seat Available: 1
#   2. chhapra-math (22531)
#      GKP (08:30:00) → MTJ (21:30:00)
#      Distance: 702.0 km | Duration: 12h 45m hrs | Seat Available: 0
#   3. KSJ-BTE PASS (55341)
#      MTJ (20:50:00) → BTE (23:00:00)
#      Distance: 62.0 km | Duration: 1h 37m hrs | Seat Available: 1
#   4. UHP-KOTA WEE (19806)
#      BTE (06:55:00) → KOTA (11:10:00)
#      Distance: 286.0 km | Duration: 6h 21m hrs | Seat Available: 1
#
# Route 148:
# - Trains required: 4
# - Total distance: 4593.0 km
# - Total duration: 113h 20m
# - Estimated cost: ₹4593.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SDAH BUI EXP (13105)
#      BJU (23:55:00) → BUI (06:10:00)
#      Distance: 212.0 km | Duration: 4h 42m hrs | Seat Available: 1
#   3. BUI - SHG  P (55137)
#      BUI (05:25:00) → SHG (11:15:00)
#      Distance: 167.0 km | Duration: 3h 42m hrs | Seat Available: 0
#   4. PNBE- KOTA (13237)
#      SHG (18:18:00) → KOTA (12:55:00)
#      Distance: 929.0 km | Duration: 16h 53m hrs | Seat Available: 1
#
# Route 149:
# - Trains required: 4
# - Total distance: 5154.0 km
# - Total duration: 119h 41m
# - Estimated cost: ₹5154.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DELHI JIND P (54033)
#      DLI (17:25:00) → NRW (22:25:00)
#      Distance: 160.0 km | Duration: 3h 33m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      NRW (09:30:00) → KOTA (23:50:00)
#      Distance: 619.0 km | Duration: 11h 15m hrs | Seat Available: 1
#
# Route 150:
# - Trains required: 4
# - Total distance: 5231.0 km
# - Total duration: 119h 35m
# - Estimated cost: ₹5231.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DELHI JIND J (54035)
#      DLI (15:40:00) → JHL (21:40:00)
#      Distance: 199.0 km | Duration: 4h 25m hrs | Seat Available: 1
#   4. SVDK-KOTA WE (19804)
#      JHL (08:50:00) → KOTA (23:50:00)
#      Distance: 657.0 km | Duration: 11h 56m hrs | Seat Available: 1
#
# Route 151:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4h 30m hrs | Seat Available: 1
#   4. PNBE- KOTA (13237)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8h 2m hrs | Seat Available: 1
#
# Route 152:
# - Trains required: 4
# - Total distance: 4980.0 km
# - Total duration: 112h 6m
# - Estimated cost: ₹4980.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 56h 38m hrs | Seat Available: 1
#   2. SIKKIM MAHAN (15483)
#      BJU (23:05:00) → DLI (22:40:00)
#      Distance: 1090.0 km | Duration: 18h 10m hrs | Seat Available: 1
#   3. DLI-TDL MEMU (64584)
#      DLI (12:55:00) → TDL (18:10:00)
#      Distance: 203.0 km | Duration: 4h 30m hrs | Seat Available: 1
#   4. PNBE-KOTA EX (13239)
#      TDL (04:25:00) → KOTA (12:55:00)
#      Distance: 402.0 km | Duration: 8h 2m hrs | Seat Available: 1
#
# Route 153:
# - Trains required: 4
# - Total distance: 4536.0 km
# - Total duration: 120h 51m
# - Estimated cost: ₹4536.0
#   Segments:
#   1. NIZAMUDDIN E (12643)
#      PGT (21:30:00) → NZM (17:10:00)
#      Distance: 2635.0 km | Duration: 45h 25m hrs | Seat Available: 1
#   2. HW BL SUP EX (12912)
#      NZM (23:35:00) → BL (18:20:00)
#      Distance: 1176.0 km | Duration: 19h 36m hrs | Seat Available: 1
#   3. BL-DHD INTER (12929)
#      BL (07:15:00) → DHD (13:25:00)
#      Distance: 344.0 km | Duration: 6h 52m hrs | Seat Available: 1
#   4. BRC-KOTA PAR (59831)
#      DHD (11:25:00) → KOTA (22:30:00)
#      Distance: 381.0 km | Duration: 7h 37m hrs | Seat Available: 1
#
# Recommendations:
# - Fastest route: Route 44 (100h 17m)
# - Shortest route: Route 59 (2646.0 km)
# - Cheapest route: Route 59 (₹2646.0)
#
# Detailed routes saved to: PGT_to_KOTA_routes.csv

# %%
# import pandas as pd
# import numpy as np
# import networkx as nx
# import matplotlib.pyplot as plt
# import plotly.graph_objects as go
# from uuid import uuid4

# def convert_to_minutes(duration_str):
#     """Convert duration string (e.g., '53h 5m') to minutes."""
#     try:
#         if pd.isna(duration_str):
#             return np.nan
#         h, m = duration_str.lower().replace('h', '').replace('m', '').split()
#         return int(h) * 60 + int(m)
#     except:
#         return np.nan

# def load_and_clean_data(file_path):
#     """Load and preprocess train route data."""
#     try:
#         df = pd.read_csv(file_path)
#     except FileNotFoundError:
#         raise FileNotFoundError("CSV file not found.")

#     df_available = df[df["Seat Availability"] == 1].copy()
#     df_available["Total Duration (min)"] = df_available["Total Route Duration"].apply(convert_to_minutes)
#     df_available = df_available.dropna(subset=["Total Duration (min)"])

#     # Calculate waiting time between segments (if applicable)
#     df_available = df_available.sort_values(["Route Number", "Segment Number"])
#     df_available["Next Departure"] = df_available.groupby("Route Number")["Departure Time"].shift(-1)
#     df_available["Arrival Time"] = pd.to_datetime(df_available["Arrival Time"], format="%H:%M", errors="coerce")
#     df_available["Next Departure"] = pd.to_datetime(df_available["Next Departure"], format="%H:%M", errors="coerce")
#     df_available["Waiting Time (min)"] = (
#         (df_available["Next Departure"] - df_available["Arrival Time"]).dt.total_seconds() / 60
#     ).fillna(0)

#     return df_available

# def calculate_multi_objective_score(df_routes):
#     """Calculate a normalized multi-objective score for routes."""
#     # Normalize features (min-max normalization)
#     df_routes["Norm Duration"] = (
#         df_routes["Total Duration (min)"] - df_routes["Total Duration (min)"].min()
#     ) / (df_routes["Total Duration (min)"].max() - df_routes["Total Duration (min)"].min() + 1e-6)

#     df_routes["Norm Cost"] = (
#         df_routes["Estimated Cost (₹)"] - df_routes["Estimated Cost (₹)"].min()
#     ) / (df_routes["Estimated Cost (₹)"].max() - df_routes["Estimated Cost (₹)"].min() + 1e-6)

#     df_routes["Norm Transfers"] = (
#         df_routes["Num Transfers"] - df_routes["Num Transfers"].min()
#     ) / (df_routes["Num Transfers"].max() - df_routes["Num Transfers"].min() + 1e-6)

#     df_routes["Norm Waiting"] = (
#         df_routes["Total Waiting (min)"] - df_routes["Total Waiting (min)"].min()
#     ) / (df_routes["Total Waiting (min)"].max() - df_routes["Total Waiting (min)"].min() + 1e-6)

#     # Weighted score (adjust weights based on priority)
#     weights = {
#         "duration": 0.4,
#         "cost": 0.3,
#         "transfers": 0.2,
#         "waiting": 0.1
#     }
#     df_routes["Score"] = (
#         weights["duration"] * df_routes["Norm Duration"] +
#         weights["cost"] * df_routes["Norm Cost"] +
#         weights["transfers"] * df_routes["Norm Transfers"] +
#         weights["waiting"] * df_routes["Norm Waiting"]
#     )

#     return df_routes

# def optimize_routes(df_available):
#     """Find optimal and near-optimal routes using multi-objective optimization."""
#     # Aggregate route-level metrics
#     df_routes = df_available.groupby("Route Number").agg({
#         "Total Duration (min)": "first",
#         "Estimated Cost (₹)": "first",
#         "Total Route Distance (km)": "first",
#         "Segment Number": "count",
#         "Waiting Time (min)": "sum"
#     }).reset_index()

#     df_routes["Num Transfers"] = df_routes["Segment Number"] - 1
#     df_routes["Total Waiting (min)"] = df_routes["Waiting Time (min)"]

#     # Calculate multi-objective score
#     df_routes = calculate_multi_objective_score(df_routes)

#     # Find optimal route (lowest score)
#     optimal_route = df_routes.loc[df_routes["Score"].idxmin()]

#     # Find near-optimal routes (within 10% of best score)
#     threshold_score = optimal_route["Score"] * 1.1
#     near_optimal_routes = df_routes[
#         (df_routes["Score"] <= threshold_score) &
#         (df_routes["Route Number"] != optimal_route["Route Number"])
#     ].sort_values("Score").head(5)

#     return optimal_route, near_optimal_routes

# def visualize_route_interactive(df, optimal_route_number):
#     """Create an interactive visualization of the optimal route using Plotly."""
#     G = nx.DiGraph()
#     optimal_segments = df[df["Route Number"] == optimal_route_number]

#     for _, row in optimal_segments.iterrows():
#         G.add_edge(
#             row["From Station"],
#             row["To Station"],
#             label=f'{row["Train Name"]} ({row["Segment Duration (hrs)"]} hrs)',
#             duration=row["Segment Duration (hrs)"],
#             train=row["Train Name"]
#         )

#     # Linear layout for sequential stations
#     pos = {station: (i, 0) for i, station in enumerate(G.nodes())}

#     # Prepare Plotly traces
#     edge_x, edge_y = [], []
#     edge_text = []
#     for edge in G.edges():
#         x0, y0 = pos[edge[0]]
#         x1, y1 = pos[edge[1]]
#         edge_x.extend([x0, x1, None])
#         edge_y.extend([y0, y1, None])
#         edge_text.append(G[edge[0]][edge[1]]["label"])

#     edge_trace = go.Scatter(
#         x=edge_x, y=edge_y,
#         line=dict(width=2, color='blue'),
#         hoverinfo='none',
#         mode='lines'
#     )

#     node_x, node_y = [], []
#     for node in G.nodes():
#         x, y = pos[node]
#         node_x.append(x)
#         node_y.append(y)

#     node_trace = go.Scatter(
#         x=node_x, y=node_y,
#         mode='markers+text',
#         text=list(G.nodes()),
#         textposition="top center",
#         marker=dict(size=20, color='lightblue', line=dict(width=2, color='black')),
#         hoverinfo='text'
#     )

#     # Create figure
#     fig = go.Figure(data=[edge_trace, node_trace],
#                     layout=go.Layout(
#                         title="🚆 Optimal Train Route: Palakkad to Kota",
#                         showlegend=False,
#                         hovermode='closest',
#                         margin=dict(b=20, l=5, r=5, t=40),
#                         xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
#                         yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)
#                     ))

#     # Add edge annotations
#     for i, edge in enumerate(G.edges()):
#         x0, y0 = pos[edge[0]]
#         x1, y1 = pos[edge[1]]
#         fig.add_annotation(
#             x=(x0 + x1) / 2, y=(y0 + y1) / 2 + 0.1,
#             text=G[edge[0]][edge[1]]["label"],
#             showarrow=False,
#             font=dict(size=10)
#         )

#     fig.show()

# def visualize_pareto_front(df_routes):
#     """Visualize the Pareto front for duration vs. cost."""
#     fig = go.Figure()

#     # Scatter plot of all routes
#     fig.add_trace(go.Scatter(
#         x=df_routes["Total Duration (min)"],
#         y=df_routes["Estimated Cost (₹)"],
#         mode='markers',
#         marker=dict(size=8, color=df_routes["Score"], colorscale='Viridis', showscale=True),
#         text=df_routes["Route Number"],
#         hovertemplate="Route: %{text}<br>Duration: %{x} min<br>Cost: ₹%{y}<br>Score: %{marker.color:.2f}"
#     ))

#     # Highlight optimal route
#     optimal_route = df_routes.loc[df_routes["Score"].idxmin()]
#     fig.add_trace(go.Scatter(
#         x=[optimal_route["Total Duration (min)"]],
#         y=[optimal_route["Estimated Cost (₹)"]],
#         mode='markers',
#         marker=dict(size=12, color='red', symbol='star'),
#         name='Optimal Route'
#     ))

#     fig.update_layout(
#         title="Pareto Front: Duration vs. Cost",
#         xaxis_title="Total Duration (min)",
#         yaxis_title="Estimated Cost (₹)",
#         showlegend=True
#     )

#     fig.show()

# def main(file_path):
#     # Load and clean data
#     df_available = load_and_clean_data(file_path)

#     # Optimize routes
#     optimal_route, near_optimal_routes = optimize_routes(df_available)

#     # Print results
#     print("\n✅ Optimal Route Details:")
#     print(optimal_route[["Route Number", "Total Duration (min)", "Estimated Cost (₹)",
#                         "Num Transfers", "Total Waiting (min)", "Score"]])

#     print("\n📌 Segments in Optimal Route:")
#     optimal_segments = df_available[df_available["Route Number"] == optimal_route["Route Number"]]
#     print(optimal_segments[[
#         "Segment Number", "Train Name", "From Station", "Departure Time",
#         "To Station", "Arrival Time", "Segment Distance (km)", "Segment Duration (hrs)"
#     ]])

#     print("\n📊 Near-Optimal Routes (within 10% of best score):")
#     print(near_optimal_routes[[
#         "Route Number", "Total Duration (min)", "Estimated Cost (₹)",
#         "Num Transfers", "Total Waiting (min)", "Score"
#     ]])

#     # Visualize optimal route
#     visualize_route_interactive(df_available, optimal_route["Route Number"])

#     # Visualize Pareto front
#     df_routes = df_available.groupby("Route Number").agg({
#         "Total Duration (min)": "first",
#         "Estimated Cost (₹)": "first",
#         "Segment Number": "count",
#         "Waiting Time (min)": "sum"
#     }).reset_index()
#     df_routes["Num Transfers"] = df_routes["Segment Number"] - 1
#     df_routes["Total Waiting (min)"] = df_routes["Waiting Time (min)"]
#     df_routes = calculate_multi_objective_score(df_routes)
#     visualize_pareto_front(df_routes)

# if __name__ == "__main__":
#     file_path = "PGT_to_KOTA_routes.csv"
#     main(file_path)

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# Load the CSV file (update path as needed)
file_path = "PGT_to_KOTA_routes.csv"
df = pd.read_csv(file_path)

# Convert 'Total Route Duration' (like "53h 5m") to minutes
def convert_to_minutes(duration_str):
    try:
        h, m = duration_str.lower().replace('h', '').replace('m', '').split()
        return int(h) * 60 + int(m)
    except:
        return np.nan

# Filter only routes with seat availability
df_available = df[df["Seat Availability"] == 1].copy()
df_available["Total Duration (min)"] = df_available["Total Route Duration"].apply(convert_to_minutes)

# Group by route to get one row per route
df_routes = df_available.groupby("Route Number").agg({
    "Total Duration (min)": "first",
    "Estimated Cost (₹)": "first",
    "Total Route Distance (km)": "first"
}).reset_index()

# Find optimal route (min time, then min cost)
min_time = df_routes["Total Duration (min)"].min()
best_routes = df_routes[df_routes["Total Duration (min)"] == min_time]
optimal_route = best_routes.loc[best_routes["Estimated Cost (₹)"].idxmin()]
optimal_route_number = optimal_route["Route Number"]

print("\n✅ Optimal Route Details:")
print(optimal_route)

# Show full route segments
optimal_segments = df[df["Route Number"] == optimal_route_number]

print("\n📌 Segments in Optimal Route:")
print(optimal_segments[[
    "Segment Number", "Train Name", "From Station", "Departure Time",
    "To Station", "Arrival Time", "Segment Distance (km)", "Segment Duration (hrs)"
]])

# Find near-optimal routes (within 30 mins of best time)
threshold_time = min_time + 30
near_optimal_routes = df_routes[
    (df_routes["Total Duration (min)"] <= threshold_time) &
    (df_routes["Route Number"] != optimal_route_number)
].sort_values(["Total Duration (min)", "Estimated Cost (₹)"])

print("\n📊 Near-Optimal Routes (within 30 mins):")
print(near_optimal_routes)

# Visualize optimal route as a graph
G = nx.DiGraph()

for _, row in optimal_segments.iterrows():
    G.add_edge(
        row["From Station"],
        row["To Station"],
        label=f'{row["Train Name"]} ({row["Segment Duration (hrs)"]} hrs)'
    )

pos = nx.spring_layout(G, seed=42)
plt.figure(figsize=(10, 6))
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=3000, font_size=10, font_weight='bold', arrows=True)
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=9)
plt.title("🚆 Optimal Train Route: Palakkad to Kota")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-10bfe14768f9> in <cell line: 0>()
#       6 # Load the CSV file (update path as needed)
#       7 file_path = "PGT_to_KOTA_routes.csv"
# ----> 8 df = pd.read_csv(file_path)
#       9
#      10 # Convert 'Total Route Duration' (like "53h 5m") to minutes
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PGT_to_KOTA_routes.csv'

# %%
import pandas as pd
from collections import deque
from datetime import datetime, timedelta

def main():
    print("\n=== Train Route Finder ===")
    print("Finds connecting routes between any two stations with distance, time, and cost calculations\n")

    # Load the data
    try:
        df = pd.read_csv('Train_details.csv')
        print("Successfully loaded train schedule data.")
    except FileNotFoundError:
        print("Error: Could not find 'Train_details.csv'. Please ensure the file is in the same directory.")
        return
    except Exception as e:
        print(f"Error loading data: {str(e)}")
        return

    # Get user input
    while True:
        print("\nEnter station codes (3-4 letter codes like PGT, KOTA, etc.)")
        source = input("Enter origin station code: ").strip().upper()
        destination = input("Enter destination station code: ").strip().upper()

        # Validate stations exist
        if source not in df['Station Code'].values:
            print(f"Error: Station code '{source}' not found in database.")
            continue
        if destination not in df['Station Code'].values:
            print(f"Error: Station code '{destination}' not found in database.")
            continue
        break

    while True:
        try:
            max_connections = int(input("Enter maximum number of connections (1-4 recommended): "))
            if 0 <= max_connections <= 4:
                break
            print("Please enter a number between 0 and 4")
        except ValueError:
            print("Please enter a valid number")

    output_file = f"{source}_to_{destination}_routes.csv"

    # Find and save routes
    routes_df = find_and_save_routes(df, source, destination, max_connections, output_file)

    if routes_df is not None:
        print("\nAnalysis of found routes:")
        analyze_routes(routes_df)
        print(f"\nDetailed routes saved to: {output_file}")

def find_and_save_routes(df, source, destination, max_connections=3, output_file='connecting_routes.csv'):
    """Find routes between stations and save to CSV with metrics"""

    # Create a graph: {station: {train_no: destination_station}}
    graph = {}
    train_info = {}

    # Build the graph and train information
    for _, row in df.iterrows():
        train_no = row['Train No']
        station = row['Station Code']
        dest_station = row['Destination Station']
        distance = row['Distance']

        if station not in graph:
            graph[station] = {}
        if train_no not in graph[station]:
            graph[station][train_no] = dest_station

        # Store train information
        if train_no not in train_info:
            train_info[train_no] = {
                'name': row['Train Name'],
                'seq': {},
                'source': row['Source Station'],
                'dest': row['Destination Station']
            }

        train_info[train_no]['seq'][row['SEQ']] = {
            'station': station,
            'arrival': row['Arrival time'],
            'departure': row['Departure Time'],
            'distance': distance
        }

    # Helper function to calculate time difference in hours
    def calculate_time_diff(start_time, end_time):
        try:
            fmt = '%H:%M:%S'
            t1 = datetime.strptime(start_time, fmt)
            t2 = datetime.strptime(end_time, fmt)

            # Handle overnight trains
            if t2 < t1:
                t2 += timedelta(days=1)

            return (t2 - t1).total_seconds() / 3600  # Convert to hours
        except:
            return 0

    # Find nearby junctions with direct trains to destination
    def find_nearby_junctions_with_direct_trains(source, destination, max_distance=100):
        nearby_junctions = set()

        # Find all stations within 100 km of source
        source_stations = set()
        for train_no, info in train_info.items():
            for seq, seq_info in info['seq'].items():
                if seq_info['station'] == source:
                    source_distance = float(seq_info['distance'])
                    # Find all stations on this train within 100 km
                    for other_seq, other_info in info['seq'].items():
                        other_distance = float(other_info['distance'])
                        if abs(other_distance - source_distance) <= max_distance:
                            source_stations.add(other_info['station'])

        # Check which of these stations have direct trains to destination
        for station in source_stations:
            if station in graph:
                for train_no in graph[station]:
                    # Check if this train goes to destination
                    seq_info = train_info[train_no]['seq']
                    stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
                    if destination in stations_in_order:
                        from_idx = stations_in_order.index(station)
                        to_idx = stations_in_order.index(destination)
                        if to_idx > from_idx:
                            nearby_junctions.add(station)

        return nearby_junctions

    # Find nearby junctions with direct trains to destination
    nearby_junctions = find_nearby_junctions_with_direct_trains(source, destination)

    # BFS implementation to find routes with max_connections
    def bfs(start, end, max_depth):
        queue = deque()
        queue.append((start, [], 0))
        visited = set()
        routes = []

        while queue:
            current, path, depth = queue.popleft()

            if current == end:
                routes.append(path)
                continue

            if depth >= max_depth:
                continue

            if current in visited:
                continue

            visited.add(current)

            if current not in graph:
                continue

            for train_no, next_station in graph[current].items():
                seq_info = train_info[train_no]['seq']
                stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]

                try:
                    current_idx = stations_in_order.index(current)
                    next_idx = stations_in_order.index(next_station)
                    if next_idx > current_idx:
                        new_path = path + [(train_no, current, next_station)]
                        queue.append((next_station, new_path, depth + 1))
                except ValueError:
                    continue

        return routes

    # Find all possible routes (original + via nearby junctions)
    all_routes = []

    # 1. Find direct routes (original BFS)
    for connections in range(1, max_connections + 1):
        routes = bfs(source, destination, connections)
        all_routes.extend(routes)

    # 2. Find routes via nearby junctions with direct trains to destination
    for junction in nearby_junctions:
        # Route from source to junction (max 1 connection)
        to_junction_routes = bfs(source, junction, 1)

        # Direct route from junction to destination
        for train_no in graph.get(junction, {}):
            seq_info = train_info[train_no]['seq']
            stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
            if destination in stations_in_order:
                from_idx = stations_in_order.index(junction)
                to_idx = stations_in_order.index(destination)
                if to_idx > from_idx:
                    direct_segment = [(train_no, junction, destination)]
                    # Combine with routes to junction
                    for route in to_junction_routes:
                        combined_route = route + direct_segment
                        all_routes.append(combined_route)

    # Prepare data for CSV
    csv_data = []
    for route_num, route in enumerate(all_routes, 1):
        total_trains = len(route)
        total_distance = 0
        total_duration_hours = 0
        route_segments = []

        # Calculate route statistics
        for segment in route:
            train_no, from_station, to_station = segment
            train_name = train_info[train_no]['name']

            # Get segment details
            seq_info = train_info[train_no]['seq']
            for seq, info in seq_info.items():
                if info['station'] == from_station:
                    departure = info['departure']
                    from_distance = float(info['distance']) # Convert to numeric type before operation
                if info['station'] == to_station:
                    arrival = info['arrival']
                    to_distance = float(info['distance']) # Convert to numeric type before operation

            # Calculate segment distance
            segment_distance = abs(to_distance - from_distance)
            total_distance += segment_distance


            if segment_distance >2500:
                segment_duration = segment_distance/65

            elif segment_distance > 2000:
                segment_duration = segment_distance/68.5

            elif segment_distance > 1450:
                segment_duration = segment_distance/72.5

            elif segment_distance > 800:
                segment_duration = segment_distance/80
            elif segment_distance > 300:
                segment_duration = segment_distance/60

            elif segment_distance > 300:
                segment_duration = segment_distance/60


            else:
                segment_duration = segment_distance/37.5


            seg_hours = int(segment_duration)
            seg_minutes = int((segment_duration % 1) * 60)
            segment_duration_str = f"{seg_hours}h {seg_minutes}m"

            total_duration_hours += segment_duration

             # Add waiting time for subsequent segments
            if route.index(segment) > 0:
                prev_arrival = route_segments[-1]['Arrival Time']
                wait_time = calculate_time_diff(prev_arrival, departure)
                if wait_time < 0:
                    wait_time += 24  # Next day
                total_duration_hours += wait_time

            route_segments.append({
                'Train Number': train_no,
                'Train Name': train_name,
                'From Station': from_station,
                'Departure Time': departure,
                'To Station': to_station,
                'Arrival Time': arrival,
                'Segment Distance (km)': segment_distance,
                'Segment Duration (hrs)': segment_duration_str,

            })


        # Calculate total route cost (₹1 per km)
        total_cost = total_distance * 1

       # Format total duration
        hours = int(total_duration_hours)
        minutes = int((total_duration_hours % 1) * 60)
        total_duration = f"{hours}h {minutes}m"

        # Add route summary and segments to CSV data
        for segment_num, segment in enumerate(route_segments, 1):
            csv_data.append({
                'Route Number': route_num,
                'Total Trains in Route': total_trains,
                'Segment Number': segment_num,
                'Train Number': segment['Train Number'],
                'Train Name': segment['Train Name'],
                'From Station': segment['From Station'],
                'Departure Time': segment['Departure Time'],
                'To Station': segment['To Station'],
                'Arrival Time': segment['Arrival Time'],
                'Segment Distance (km)': segment['Segment Distance (km)'],
                'Segment Duration (hrs)': segment['Segment Duration (hrs)'],
                'Total Route Distance (km)': total_distance,
                'Total Route Duration': total_duration,
                'Estimated Cost (₹)': total_cost
            })

    # Create DataFrame and save to CSV
    if csv_data:
        routes_df = pd.DataFrame(csv_data)

        # Reorder columns for better readability
        columns = [
            'Route Number', 'Total Trains in Route', 'Segment Number',
            'Train Number', 'Train Name', 'From Station', 'Departure Time',
            'To Station', 'Arrival Time', 'Segment Distance (km)',
            'Segment Duration (hrs)', 'Total Route Distance (km)',
            'Total Route Duration', 'Estimated Cost (₹)'
        ]
        routes_df = routes_df[columns]

        routes_df.to_csv(output_file, index=False)
        print(f"\nSuccessfully saved {len(all_routes)} routes to {output_file}")

        return routes_df
    else:
        print("\nNo valid routes found with the given parameters.")
        return None

def analyze_routes(routes_df):
    """Analyze and display summary statistics about found routes"""
    # Get unique routes
    unique_routes = routes_df['Route Number'].unique()

    print(f"\nFound {len(unique_routes)} unique routes:")

    # Print summary for each route
    for route_num in unique_routes:
        route_data = routes_df[routes_df['Route Number'] == route_num]
        first_row = route_data.iloc[0]

        print(f"\nRoute {route_num}:")
        print(f"- Trains required: {first_row['Total Trains in Route']}")
        print(f"- Total distance: {first_row['Total Route Distance (km)']} km")
        print(f"- Total duration: {first_row['Total Route Duration']}")
        print(f"- Estimated cost: ₹{first_row['Estimated Cost (₹)']}")

        # Print segments
        print("  Segments:")
        for _, segment in route_data.iterrows():
            print(f"  {segment['Segment Number']}. {segment['Train Name']} ({segment['Train Number']})")
            print(f"     {segment['From Station']} ({segment['Departure Time']}) → {segment['To Station']} ({segment['Arrival Time']})")
            print(f"     Distance: {segment['Segment Distance (km)']} km | Duration: {segment['Segment Duration (hrs)']} hrs")

    # Find fastest and shortest routes
    routes_summary = routes_df.drop_duplicates('Route Number')

    if len(routes_summary) > 1:
        fastest = routes_summary.loc[routes_summary['Total Route Duration'].idxmin()]
        shortest = routes_summary.loc[routes_summary['Total Route Distance (km)'].idxmin()]
        cheapest = routes_summary.loc[routes_summary['Estimated Cost (₹)'].idxmin()]

        print("\nRecommendations:")
        print(f"- Fastest route: Route {fastest['Route Number']} ({fastest['Total Route Duration']})")
        print(f"- Shortest route: Route {shortest['Route Number']} ({shortest['Total Route Distance (km)']} km)")
        print(f"- Cheapest route: Route {cheapest['Route Number']} (₹{cheapest['Estimated Cost (₹)']})")

if __name__ == "__main__":
    main()
# Out:
# === Train Route Finder ===
# Finds connecting routes between any two stations with distance, time, and cost calculations
# <ipython-input-7-de9ce1933a15>:11: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Train_details.csv')
# Successfully loaded train schedule data.
#
# Enter station codes (3-4 letter codes like PGT, KOTA, etc.)
# Enter origin station code: PGT
# Enter destination station code: GKP
# Enter maximum number of connections (1-4 recommended): 2
#
# Successfully saved 46 routes to PGT_to_GKP_routes.csv
#
# Analysis of found routes:
#
# Found 46 unique routes:
#
# Route 1:
# - Trains required: 1
# - Total distance: 2889.0 km
# - Total duration: 44h 26m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 44h 26m hrs
#
# Route 2:
# - Trains required: 1
# - Total distance: 2889.0 km
# - Total duration: 44h 26m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 44h 26m hrs
#
# Route 3:
# - Trains required: 2
# - Total distance: 2890.0 km
# - Total duration: 58h 4m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. ERS-MAS SPL (6006)
#      PGT (23:10:00) → MAS (10:30:00)
#      Distance: 549.0 km | Duration: 10h 58m hrs
#   2. RAPTISAGAR E (12512)
#      MAS (23:25:00) → GKP (15:20:00)
#      Distance: 2341.0 km | Duration: 34h 10m hrs
#
# Route 4:
# - Trains required: 2
# - Total distance: 3485.0 km
# - Total duration: 75h 16m
# - Estimated cost: ₹3485.0
#   Segments:
#   1. MAS-QLN SPEC (6041)
#      PGT (03:30:00) → QLN (11:00:00)
#      Distance: 304.0 km | Duration: 6h 4m hrs
#   2. RAPTISAGAR E (12512)
#      QLN (07:15:00) → GKP (15:20:00)
#      Distance: 3181.0 km | Duration: 48h 56m hrs
#
# Route 5:
# - Trains required: 2
# - Total distance: 3190.0 km
# - Total duration: 74h 31m
# - Estimated cost: ₹3190.0
#   Segments:
#   1. YPR-ERS WEEK (6547)
#      PGT (06:55:00) → ERS (10:30:00)
#      Distance: 150.0 km | Duration: 4h 0m hrs
#   2. RAPTISAGAR E (12512)
#      ERS (10:15:00) → GKP (15:20:00)
#      Distance: 3040.0 km | Duration: 46h 46m hrs
#
# Route 6:
# - Trains required: 2
# - Total distance: 2988.0 km
# - Total duration: 61h 2m
# - Estimated cost: ₹2988.0
#   Segments:
#   1. ERS-YPR WEEK (6548)
#      PGT (19:20:00) → YPR (04:30:00)
#      Distance: 484.0 km | Duration: 9h 40m hrs
#   2. SBC-GKP EXP (12592)
#      YPR (17:20:00) → GKP (15:05:00)
#      Distance: 2504.0 km | Duration: 38h 31m hrs
#
# Route 7:
# - Trains required: 2
# - Total distance: 2988.0 km
# - Total duration: 51h 17m
# - Estimated cost: ₹2988.0
#   Segments:
#   1. ERS-YPR WEEK (6548)
#      PGT (19:20:00) → YPR (04:30:00)
#      Distance: 484.0 km | Duration: 9h 40m hrs
#   2. YPR - GKP EX (15016)
#      YPR (07:35:00) → GKP (13:30:00)
#      Distance: 2504.0 km | Duration: 38h 31m hrs
#
# Route 8:
# - Trains required: 2
# - Total distance: 2957.0 km
# - Total duration: 64h 56m
# - Estimated cost: ₹2957.0
#   Segments:
#   1. ERS-YPR WEEK (6548)
#      PGT (19:20:00) → YPR (04:30:00)
#      Distance: 484.0 km | Duration: 9h 40m hrs
#   2. YPR-GKP-EXP (15024)
#      YPR (23:40:00) → GKP (19:45:00)
#      Distance: 2473.0 km | Duration: 36h 6m hrs
#
# Route 9:
# - Trains required: 2
# - Total distance: 2834.0 km
# - Total duration: 58h 38m
# - Estimated cost: ₹2834.0
#   Segments:
#   1. QLN-BZA (7214)
#      PGT (16:30:00) → BZA (09:35:00)
#      Distance: 923.0 km | Duration: 11h 32m hrs
#   2. RAPTISAGAR E (12512)
#      BZA (06:20:00) → GKP (15:20:00)
#      Distance: 1911.0 km | Duration: 26h 21m hrs
#
# Route 10:
# - Trains required: 2
# - Total distance: 3613.0 km
# - Total duration: 64h 51m
# - Estimated cost: ₹3613.0
#   Segments:
#   1. SCL - TVC EX (12508)
#      PGT (14:40:00) → TVC (22:40:00)
#      Distance: 368.0 km | Duration: 7h 21m hrs
#   2. RAPTISAGAR E (12512)
#      TVC (06:15:00) → GKP (15:20:00)
#      Distance: 3245.0 km | Duration: 49h 55m hrs
#
# Route 11:
# - Trains required: 2
# - Total distance: 3679.0 km
# - Total duration: 81h 10m
# - Estimated cost: ₹3679.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 50h 32m hrs
#   2. ASANSOL-GORA (13507)
#      BJU (21:35:00) → GKP (05:50:00)
#      Distance: 394.0 km | Duration: 7h 52m hrs
#
# Route 12:
# - Trains required: 2
# - Total distance: 3678.0 km
# - Total duration: 64h 53m
# - Estimated cost: ₹3678.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 50h 32m hrs
#   2. MAURYA EXP (15027)
#      BJU (05:20:00) → GKP (17:25:00)
#      Distance: 393.0 km | Duration: 7h 51m hrs
#
# Route 13:
# - Trains required: 2
# - Total distance: 3679.0 km
# - Total duration: 59h 10m
# - Estimated cost: ₹3679.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 50h 32m hrs
#   2. PURBANCHAL E (15047)
#      BJU (23:35:00) → GKP (07:45:00)
#      Distance: 394.0 km | Duration: 7h 52m hrs
#
# Route 14:
# - Trains required: 2
# - Total distance: 3703.0 km
# - Total duration: 59h 38m
# - Estimated cost: ₹3703.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 50h 32m hrs
#   2. KKK-GKP EXP (15049)
#      BJU (23:35:00) → GKP (09:45:00)
#      Distance: 418.0 km | Duration: 8h 21m hrs
#
# Route 15:
# - Trains required: 2
# - Total distance: 3697.0 km
# - Total duration: 59h 31m
# - Estimated cost: ₹3697.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → BJU (22:50:00)
#      Distance: 3285.0 km | Duration: 50h 32m hrs
#   2. KKK GKP EXPR (15051)
#      BJU (23:35:00) → GKP (08:15:00)
#      Distance: 412.0 km | Duration: 8h 14m hrs
#
# Route 16:
# - Trains required: 2
# - Total distance: 3417.0 km
# - Total duration: 62h 53m
# - Estimated cost: ₹3417.0
#   Segments:
#   1. KERALA EXPRE (12625)
#      PGT (18:45:00) → NDLS (13:45:00)
#      Distance: 2643.0 km | Duration: 40h 39m hrs
#   2. GORAKHDHAM E (12556)
#      NDLS (20:30:00) → GKP (09:45:00)
#      Distance: 774.0 km | Duration: 15h 28m hrs
#
# Route 17:
# - Trains required: 2
# - Total distance: 3196.0 km
# - Total duration: 50h 58m
# - Estimated cost: ₹3196.0
#   Segments:
#   1. NCJ-SHM GURU (12659)
#      PGT (23:50:00) → SHM (13:50:00)
#      Distance: 2140.0 km | Duration: 31h 14m hrs
#   2. SHALIMAR-GOR (15021)
#      SHM (20:22:00) → GKP (16:25:00)
#      Distance: 1056.0 km | Duration: 13h 11m hrs
#
# Route 18:
# - Trains required: 2
# - Total distance: 3305.0 km
# - Total duration: 66h 24m
# - Estimated cost: ₹3305.0
#   Segments:
#   1. DHANBAD - AL (13351)
#      PGT (13:20:00) → ALLP (19:25:00)
#      Distance: 208.0 km | Duration: 5h 32m hrs
#   2. RAPTISAGAR E (12512)
#      ALLP (08:38:00) → GKP (15:20:00)
#      Distance: 3097.0 km | Duration: 47h 38m hrs
#
# Route 19:
# - Trains required: 2
# - Total distance: 3004.0 km
# - Total duration: 56h 10m
# - Estimated cost: ₹3004.0
#   Segments:
#   1. ALLEPY-DHANB (13352)
#      PGT (10:40:00) → DHN (13:30:00)
#      Distance: 2327.0 km | Duration: 33h 58m hrs
#   2. MAURYA EXP (15027)
#      DHN (22:10:00) → GKP (17:25:00)
#      Distance: 677.0 km | Duration: 13h 32m hrs
#
# Route 20:
# - Trains required: 2
# - Total distance: 3292.0 km
# - Total duration: 62h 54m
# - Estimated cost: ₹3292.0
#   Segments:
#   1. TVC-CSMT  EX (16332)
#      PGT (12:10:00) → CSMT (20:50:00)
#      Distance: 1598.0 km | Duration: 22h 2m hrs
#   2. CSMT-GKP -WE (12598)
#      CSMT (14:20:00) → GKP (18:35:00)
#      Distance: 1694.0 km | Duration: 23h 21m hrs
#
# Route 21:
# - Trains required: 2
# - Total distance: 3034.0 km
# - Total duration: 51h 9m
# - Estimated cost: ₹3034.0
#   Segments:
#   1. MAQ-KCG EXP (17605)
#      PGT (02:30:00) → KCG (23:50:00)
#      Distance: 1172.0 km | Duration: 14h 39m hrs
#   2. YPR-GKP-EXP (15024)
#      KCG (10:40:00) → GKP (19:45:00)
#      Distance: 1862.0 km | Duration: 25h 40m hrs
#
# Route 22:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 57h 46m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. BKN CBE AC S (22475)
#      PGT (01:15:00) → CBE (02:50:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 23:
# - Trains required: 2
# - Total distance: 2947.0 km
# - Total duration: 41h 13m
# - Estimated cost: ₹2947.0
#   Segments:
#   1. ERS HTE DHAR (22838)
#      PGT (03:10:00) → HTE (17:05:00)
#      Distance: 2088.0 km | Duration: 30h 28m hrs
#   2. MAURYA EXP (15027)
#      HTE (17:05:00) → GKP (17:25:00)
#      Distance: 859.0 km | Duration: 10h 44m hrs
#
# Route 24:
# - Trains required: 2
# - Total distance: 3043.0 km
# - Total duration: 62h 36m
# - Estimated cost: ₹3043.0
#   Segments:
#   1. CBE-TCR PASS (56605)
#      PGT (17:55:00) → TCR (20:45:00)
#      Distance: 77.0 km | Duration: 2h 3m hrs
#   2. RAPTISAGAR E (12512)
#      TCR (11:40:00) → GKP (15:20:00)
#      Distance: 2966.0 km | Duration: 45h 37m hrs
#
# Route 25:
# - Trains required: 2
# - Total distance: 2977.0 km
# - Total duration: 46h 57m
# - Estimated cost: ₹2977.0
#   Segments:
#   1. CBE-SRR PASS (66605)
#      PGT (11:05:00) → SRR (12:30:00)
#      Distance: 44.0 km | Duration: 1h 10m hrs
#   2. RAPTISAGAR E (12512)
#      SRR (13:10:00) → GKP (15:20:00)
#      Distance: 2933.0 km | Duration: 45h 7m hrs
#
# Route 26:
# - Trains required: 2
# - Total distance: 2888.0 km
# - Total duration: 68h 20m
# - Estimated cost: ₹2888.0
#   Segments:
#   1. PGTN-ED MEMU (66608)
#      PGT (14:45:00) → ED (19:05:00)
#      Distance: 154.0 km | Duration: 4h 6m hrs
#   2. RAPTISAGAR E (12512)
#      ED (17:15:00) → GKP (15:20:00)
#      Distance: 2734.0 km | Duration: 42h 3m hrs
#
# Route 27:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 57h 46m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. BKN CBE AC S (22475)
#      PGT (01:15:00) → CBE (02:50:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 28:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 65h 31m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. MAQ-CBE INTE (22609)
#      PGT (17:35:00) → CBE (19:05:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 29:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 65h 1m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. MAQ-CBE FAST (56324)
#      PGT (17:50:00) → CBE (19:35:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 30:
# - Trains required: 2
# - Total distance: 2890.0 km
# - Total duration: 49h 47m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. SRR-CBE PASS (56604)
#      PGT (09:05:00) → CBE (10:50:00)
#      Distance: 55.0 km | Duration: 1h 27m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 31:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 47h 11m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. CAN-CBE PASS (56650)
#      PGT (11:20:00) → CBE (13:25:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 32:
# - Trains required: 2
# - Total distance: 2890.0 km
# - Total duration: 66h 57m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. SRR CBE PASS (66604)
#      PGT (15:55:00) → CBE (17:40:00)
#      Distance: 55.0 km | Duration: 1h 27m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 33:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 51h 46m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. PGTN-CBE PAS (66606)
#      PGT (07:28:00) → CBE (08:50:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTISAGAR E (12512)
#      CBE (15:33:00) → GKP (15:20:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 34:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 57h 46m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. BKN CBE AC S (22475)
#      PGT (01:15:00) → CBE (02:50:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 35:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 65h 31m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. MAQ-CBE INTE (22609)
#      PGT (17:35:00) → CBE (19:05:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 36:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 65h 1m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. MAQ-CBE FAST (56324)
#      PGT (17:50:00) → CBE (19:35:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 37:
# - Trains required: 2
# - Total distance: 2890.0 km
# - Total duration: 49h 47m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. SRR-CBE PASS (56604)
#      PGT (09:05:00) → CBE (10:50:00)
#      Distance: 55.0 km | Duration: 1h 27m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 38:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 47h 11m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. CAN-CBE PASS (56650)
#      PGT (11:20:00) → CBE (13:25:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 39:
# - Trains required: 2
# - Total distance: 2890.0 km
# - Total duration: 66h 57m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. SRR CBE PASS (66604)
#      PGT (15:55:00) → CBE (17:40:00)
#      Distance: 55.0 km | Duration: 1h 27m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 40:
# - Trains required: 2
# - Total distance: 2889.0 km
# - Total duration: 51h 46m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. PGTN-CBE PAS (66606)
#      PGT (07:28:00) → CBE (08:50:00)
#      Distance: 54.0 km | Duration: 1h 26m hrs
#   2. RAPTI SAGAR (12522)
#      CBE (15:33:00) → GKP (15:15:00)
#      Distance: 2835.0 km | Duration: 43h 36m hrs
#
# Route 41:
# - Trains required: 2
# - Total distance: 2977.0 km
# - Total duration: 46h 57m
# - Estimated cost: ₹2977.0
#   Segments:
#   1. CBE-SRR PASS (66605)
#      PGT (11:05:00) → SRR (12:30:00)
#      Distance: 44.0 km | Duration: 1h 10m hrs
#   2. RAPTISAGAR E (12512)
#      SRR (13:10:00) → GKP (15:20:00)
#      Distance: 2933.0 km | Duration: 45h 7m hrs
#
# Route 42:
# - Trains required: 2
# - Total distance: 2977.0 km
# - Total duration: 46h 57m
# - Estimated cost: ₹2977.0
#   Segments:
#   1. CBE-SRR PASS (66605)
#      PGT (11:05:00) → SRR (12:30:00)
#      Distance: 44.0 km | Duration: 1h 10m hrs
#   2. RAPTI SAGAR (12522)
#      SRR (13:10:00) → GKP (15:15:00)
#      Distance: 2933.0 km | Duration: 45h 7m hrs
#
# Route 43:
# - Trains required: 2
# - Total distance: 3043.0 km
# - Total duration: 62h 36m
# - Estimated cost: ₹3043.0
#   Segments:
#   1. CBE-TCR PASS (56605)
#      PGT (17:55:00) → TCR (20:45:00)
#      Distance: 77.0 km | Duration: 2h 3m hrs
#   2. RAPTISAGAR E (12512)
#      TCR (11:40:00) → GKP (15:20:00)
#      Distance: 2966.0 km | Duration: 45h 37m hrs
#
# Route 44:
# - Trains required: 2
# - Total distance: 3043.0 km
# - Total duration: 62h 36m
# - Estimated cost: ₹3043.0
#   Segments:
#   1. CBE-TCR PASS (56605)
#      PGT (17:55:00) → TCR (20:45:00)
#      Distance: 77.0 km | Duration: 2h 3m hrs
#   2. RAPTI SAGAR (12522)
#      TCR (11:40:00) → GKP (15:15:00)
#      Distance: 2966.0 km | Duration: 45h 37m hrs
#
# Route 45:
# - Trains required: 1
# - Total distance: 2889.0 km
# - Total duration: 44h 26m
# - Estimated cost: ₹2889.0
#   Segments:
#   1. RAPTISAGAR E (12512)
#      PGT (14:05:00) → GKP (15:20:00)
#      Distance: 2889.0 km | Duration: 44h 26m hrs
#
# Route 46:
# - Trains required: 1
# - Total distance: 2890.0 km
# - Total duration: 44h 27m
# - Estimated cost: ₹2890.0
#   Segments:
#   1. RAPTI SAGAR (12522)
#      PGT (14:05:00) → GKP (15:15:00)
#      Distance: 2890.0 km | Duration: 44h 27m hrs
#
# Recommendations:
# - Fastest route: Route 23 (41h 13m)
# - Shortest route: Route 9 (2834.0 km)
# - Cheapest route: Route 9 (₹2834.0)
#
# Detailed routes saved to: PGT_to_GKP_routes.csv

# %%
import pandas as pd
from collections import deque
from datetime import datetime, timedelta

def main():
    print("\n=== Train Route Finder ===")
    print("Finds connecting routes between any two stations with distance, time, and cost calculations\n")

    # Load the data
    try:
        df = pd.read_csv('train_data.csv')
        print("Successfully loaded train schedule data.")
    except FileNotFoundError:
        print("Error: Could not find 'Train_details.csv'. Please ensure the file is in the same directory.")
        return
    except Exception as e:
        print(f"Error loading data: {str(e)}")
        return

    # Get user input
    while True:
        print("\nEnter station codes (3-4 letter codes like PGT, KOTA, etc.)")
        source = input("Enter origin station code: ").strip().upper()
        destination = input("Enter destination station code: ").strip().upper()

        # Validate stations exist
        if source not in df['Station Code'].values:
            print(f"Error: Station code '{source}' not found in database.")
            continue
        if destination not in df['Station Code'].values:
            print(f"Error: Station code '{destination}' not found in database.")
            continue
        break

    while True:
        try:
            max_connections = int(input("Enter maximum number of connections (1-4 recommended): "))
            if 0 <= max_connections <= 4:
                break
            print("Please enter a number between 0 and 4")
        except ValueError:
            print("Please enter a valid number")

    output_file = f"{source}_to_{destination}_routes.csv"

    # Find and save routes
    routes_df = find_and_save_routes(df, source, destination, max_connections, output_file)

    if routes_df is not None:
        print("\nAnalysis of found routes:")
        analyze_routes(routes_df)
        print(f"\nDetailed routes saved to: {output_file}")

def find_and_save_routes(df, source, destination, max_connections=3, output_file='connecting_routes.csv'):
    """Find routes between stations and save to CSV with metrics"""

    # Create a graph: {station: {train_no: destination_station}}
    graph = {}
    train_info = {}

    # Build the graph and train information
    for _, row in df.iterrows():
        train_no = row['Train No']
        station = row['Station Code']
        dest_station = row['Destination Station']
        distance = row['Distance']

        if station not in graph:
            graph[station] = {}
        if train_no not in graph[station]:
            graph[station][train_no] = dest_station

        # Store train information
        if train_no not in train_info:
            train_info[train_no] = {
                'name': row['Train Name'],
                'seq': {},
                'source': row['Source Station'],
                'dest': row['Destination Station']
            }

        train_info[train_no]['seq'][row['SEQ']] = {
            'station': station,
            'arrival': row['Arrival time'],
            'departure': row['Departure Time'],
            'distance': distance
        }

    # Helper function to calculate time difference in hours
    def calculate_time_diff(start_time, end_time):
        try:
            fmt = '%H:%M:%S'
            t1 = datetime.strptime(start_time, fmt)
            t2 = datetime.strptime(end_time, fmt)

            # Handle overnight trains
            if t2 < t1:
                t2 += timedelta(days=1)

            return (t2 - t1).total_seconds() / 3600  # Convert to hours
        except:
            return 0

    # Find nearby junctions with direct trains to destination
    def find_nearby_junctions_with_direct_trains(source, destination, max_distance=100):
        nearby_junctions = set()

        # Find all stations within 100 km of source
        source_stations = set()
        for train_no, info in train_info.items():
            for seq, seq_info in info['seq'].items():
                if seq_info['station'] == source:
                    source_distance = float(seq_info['distance'])
                    # Find all stations on this train within 100 km
                    for other_seq, other_info in info['seq'].items():
                        other_distance = float(other_info['distance'])
                        if abs(other_distance - source_distance) <= max_distance:
                            source_stations.add(other_info['station'])

        # Check which of these stations have direct trains to destination
        for station in source_stations:
            if station in graph:
                for train_no in graph[station]:
                    # Check if this train goes to destination
                    seq_info = train_info[train_no]['seq']
                    stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
                    if destination in stations_in_order:
                        from_idx = stations_in_order.index(station)
                        to_idx = stations_in_order.index(destination)
                        if to_idx > from_idx:
                            nearby_junctions.add(station)

        return nearby_junctions

    # Find nearby junctions with direct trains to destination
    nearby_junctions = find_nearby_junctions_with_direct_trains(source, destination)

    # BFS implementation to find routes with max_connections
    def bfs(start, end, max_depth):
        queue = deque()
        queue.append((start, [], 0))
        visited = set()
        routes = []

        while queue:
            current, path, depth = queue.popleft()

            if current == end:
                routes.append(path)
                continue

            if depth >= max_depth:
                continue

            if current in visited:
                continue

            visited.add(current)

            if current not in graph:
                continue

            for train_no, next_station in graph[current].items():
                seq_info = train_info[train_no]['seq']
                stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]

                try:
                    current_idx = stations_in_order.index(current)
                    next_idx = stations_in_order.index(next_station)
                    if next_idx > current_idx:
                        new_path = path + [(train_no, current, next_station)]
                        queue.append((next_station, new_path, depth + 1))
                except ValueError:
                    continue

        return routes

    # Find all possible routes (original + via nearby junctions)
    all_routes = []

    # 1. Find direct routes (original BFS)
    for connections in range(1, max_connections + 1):
        routes = bfs(source, destination, connections)
        all_routes.extend(routes)

    # 2. Find routes via nearby junctions with direct trains to destination
    for junction in nearby_junctions:
        # Route from source to junction (max 1 connection)
        to_junction_routes = bfs(source, junction, 1)

        # Direct route from junction to destination
        for train_no in graph.get(junction, {}):
            seq_info = train_info[train_no]['seq']
            stations_in_order = [v['station'] for k, v in sorted(seq_info.items(), key=lambda x: int(x[0]))]
            if destination in stations_in_order:
                from_idx = stations_in_order.index(junction)
                to_idx = stations_in_order.index(destination)
                if to_idx > from_idx:
                    direct_segment = [(train_no, junction, destination)]
                    # Combine with routes to junction
                    for route in to_junction_routes:
                        combined_route = route + direct_segment
                        all_routes.append(combined_route)

    # Prepare data for CSV
    csv_data = []
    for route_num, route in enumerate(all_routes, 1):
        total_trains = len(route)
        total_distance = 0
        total_duration_hours = 0
        route_segments = []

        # Calculate route statistics
        for segment in route:
            train_no, from_station, to_station = segment
            train_name = train_info[train_no]['name']

            # Get segment details
            seq_info = train_info[train_no]['seq']
            for seq, info in seq_info.items():
                if info['station'] == from_station:
                    departure = info['departure']
                    from_distance = float(info['distance'])
                if info['station'] == to_station:
                    arrival = info['arrival']
                    to_distance = float(info['distance'])

            # Calculate segment distance
            segment_distance = abs(to_distance - from_distance)
            total_distance += segment_distance

            # Calculate segment duration in hours
            segment_duration = segment_distance / train_info[train_no]['speed_kmph']


            # Convert to hours and minutes format
            segment_hours = int(segment_duration)
            segment_minutes = int((segment_duration % 1) * 60)
            segment_duration_str = f"{segment_hours}h {segment_minutes}m"

            total_duration_hours += segment_duration

            # Add waiting time between segments
            if route.index(segment) > 0:
                prev_arrival = route_segments[-1]['Arrival Time']
                wait_time = calculate_time_diff(prev_arrival, departure)
                if wait_time < 0:
                    wait_time += 24
                total_duration_hours += wait_time

            route_segments.append({
                'Train Number': train_no,
                'Train Name': train_name,
                'From Station': from_station,
                'Departure Time': departure,
                'To Station': to_station,
                'Arrival Time': arrival,
                'Segment Distance (km)': segment_distance,
                'Segment Duration': segment_duration_str
            })

        # Calculate total route cost (₹1 per km)
        total_cost = total_distance * 1

        # Format total duration
        total_hours = int(total_duration_hours)
        total_minutes = int((total_duration_hours % 1) * 60)
        total_duration = f"{total_hours}h {total_minutes}m"

        # Add route summary and segments to CSV data
        for segment_num, segment in enumerate(route_segments, 1):
            csv_data.append({
                'Route Number': route_num,
                'Total Trains in Route': total_trains,
                'Segment Number': segment_num,
                'Train Number': segment['Train Number'],
                'Train Name': segment['Train Name'],
                'From Station': segment['From Station'],
                'Departure Time': segment['Departure Time'],
                'To Station': segment['To Station'],
                'Arrival Time': segment['Arrival Time'],
                'Segment Distance (km)': segment['Segment Distance (km)'],
                'Segment Duration': segment['Segment Duration'],
                'Total Route Distance (km)': total_distance,
                'Total Route Duration': total_duration,
                'Estimated Cost (₹)': total_cost
            })

    # Create DataFrame and save to CSV
    if csv_data:
        routes_df = pd.DataFrame(csv_data)

        # Reorder columns for better readability
        columns = [
            'Route Number', 'Total Trains in Route', 'Segment Number',
            'Train Number', 'Train Name', 'From Station', 'Departure Time',
            'To Station', 'Arrival Time', 'Segment Distance (km)',
            'Segment Duration', 'Total Route Distance (km)',
            'Total Route Duration', 'Estimated Cost (₹)'
        ]
        routes_df = routes_df[columns]

        routes_df.to_csv(output_file, index=False)
        print(f"\nSuccessfully saved {len(all_routes)} routes to {output_file}")

        return routes_df
    else:
        print("\nNo valid routes found with the given parameters.")
        return None

def analyze_routes(routes_df):
    """Analyze and display summary statistics about found routes"""
    # Get unique routes
    unique_routes = routes_df['Route Number'].unique()

    print(f"\nFound {len(unique_routes)} unique routes:")

    # Print summary for each route
    for route_num in unique_routes:
        route_data = routes_df[routes_df['Route Number'] == route_num]
        first_row = route_data.iloc[0]

        print(f"\nRoute {route_num}:")
        print(f"- Trains required: {first_row['Total Trains in Route']}")
        print(f"- Total distance: {first_row['Total Route Distance (km)']} km")
        print(f"- Total duration: {first_row['Total Route Duration']}")
        print(f"- Estimated cost: ₹{first_row['Estimated Cost (₹)']}")

        # Print segments
        print("  Segments:")
        for _, segment in route_data.iterrows():
            print(f"  {segment['Segment Number']}. {segment['Train Name']} ({segment['Train Number']})")
            print(f"     {segment['From Station']} ({segment['Departure Time']}) → {segment['To Station']} ({segment['Arrival Time']})")
            print(f"     Distance: {segment['Segment Distance (km)']} km | Duration: {segment['Segment Duration']}")

    # Find fastest and shortest routes
    routes_summary = routes_df.drop_duplicates('Route Number')

    if len(routes_summary) > 1:
        fastest = routes_summary.loc[routes_summary['Total Route Duration'].idxmin()]
        shortest = routes_summary.loc[routes_summary['Total Route Distance (km)'].idxmin()]
        cheapest = routes_summary.loc[routes_summary['Estimated Cost (₹)'].idxmin()]

        print("\nRecommendations:")
        print(f"- Fastest route: Route {fastest['Route Number']} ({fastest['Total Route Duration']})")
        print(f"- Shortest route: Route {shortest['Route Number']} ({shortest['Total Route Distance (km)']} km)")
        print(f"- Cheapest route: Route {cheapest['Route Number']} (₹{cheapest['Estimated Cost (₹)']})")

if __name__ == "__main__":
    main()
